# %%
# Check RAM Memory

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
  
print(ram_gb)

# Login into drive

from google.colab import drive
drive.mount('/content/drive')

# Importing "load_model"

from keras.models import load_model
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# 89.63678208
# Mounted at /content/drive

# %%
import numpy as np

# Download and import data preprocessing .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
from data_processing import data_bundle as data_bundle

# Download and import performance metrics .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
from performance_metrics import plot_ROC, plot_cm, plot_acc_loss
from sklearn.metrics import classification_report

# Download and import VGG16 .py file
! wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/VGG16.py
from VGG16 import vgg16_seei as vgg16_class

# Download and import VGG16 .py file
# Out:
# --2023-05-15 03:15:19--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3860 (3.8K) [text/plain]
# Saving to: ‘data_processing.py’
#
# data_processing.py  100%[===================>]   3.77K  --.-KB/s    in 0s
#
# 2023-05-15 03:15:20 (81.8 MB/s) - ‘data_processing.py’ saved [3860/3860]
#
# --2023-05-15 03:15:20--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3235 (3.2K) [text/plain]
# Saving to: ‘performance_metrics.py’
#
# performance_metrics 100%[===================>]   3.16K  --.-KB/s    in 0s
#
# 2023-05-15 03:15:20 (45.9 MB/s) - ‘performance_metrics.py’ saved [3235/3235]
#
# --2023-05-15 03:15:20--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/VGG16.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3527 (3.4K) [text/plain]
# Saving to: ‘VGG16.py’
#
# VGG16.py            100%[===================>]   3.44K  --.-KB/s    in 0s
#
# 2023-05-15 03:15:21 (74.3 MB/s) - ‘VGG16.py’ saved [3527/3527]

# %%
# Define relevant paths for appropriately instantiating the data_bundle class
images_path_0 = "/content/drive/MyDrive/Thesis/imageset_500_500.npy"
popn_path_0 = "/content/drive/MyDrive/Thesis/siei_processed_v1.csv"
target_var = "gdp"

# In this case GDP has been chose
if target_var == "gdp":
  labels_path_0 = "/content/drive/MyDrive/Thesis/target_logGDP.npy"
  label_type = "GDPpercap"

elif target_var == "hdi":
  labels_path_0 = "/content/drive/MyDrive/Thesis/target_HDI.npy"
  label_type = "HDI"

# Instantiate data_bundle object
basic_bundle = data_bundle(images_path_0, popn_path_0, labels_path_0, label_type)

# Preprocess data through the data_bundle class' methods
basic_bundle.normalize_images()
basic_bundle.normalize_popn()
basic_bundle.bundle_inputs()
basic_bundle.split_data(0.4,0.5,2023)
basic_bundle.unbundle_and_shape_inputs()
basic_bundle.onehot_encode_labels()

# The resulting input sets are: self.X_tri, self.X_vai, self.X_tei (Images) and self.X_trp, self.X_vap, self.X_tep (Population)
# The resulting tragets are: self.y_train_onehot, self.y_val_onehot and self.y_test_onehot
# Where "self" is to be substituted by the given name to the data_bundle instance
# Out:
# /content/data_processing.py:32: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features = np.array(list(zip(self.images, np.array(self.popn))))

# %% [markdown]
# ### Model: VGG16 - GDP per capita

# %%
# Eliminar learning rate de vgg.py y pasar el dropout a argumento de método y no de clase
vgg_model = vgg16_class(input_shape=(500, 500, 3))

vgg_model.load_and_freeze_vgg16()
vgg_model.enable_dual_input()
vgg_model.add_dense_layers(dropout_rate=0.25)
vgg_model.define_and_compile_model()
vgg_model.fit_model(train_in=[basic_bundle.X_tri, basic_bundle.X_trp], train_tar=basic_bundle.y_train_onehot, 
                    validation_in=[basic_bundle.X_vai, basic_bundle.X_vap], validation_tar=basic_bundle.y_val_onehot, 
                    batch_size=32, epochs=100, es_patience=25)

# Note: if model is on single mode train_in and validation_in should have just one "input" instead of a list of two "inputs"

vgg_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])

# model Save/Load  

example_save_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"
example_load_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"

#vgg_model.save(<path_here>)
#vgg_model.load(<path_here>)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# Epoch 1/100
# 97/97 [==============================] - 34s 200ms/step - loss: 1.8994 - accuracy: 0.2891 - val_loss: 1.3373 - val_accuracy: 0.4123
# Epoch 2/100
# 97/97 [==============================] - 13s 139ms/step - loss: 1.3319 - accuracy: 0.3093 - val_loss: 1.2581 - val_accuracy: 0.3587
# Epoch 3/100
# 97/97 [==============================] - 14s 140ms/step - loss: 1.2702 - accuracy: 0.3980 - val_loss: 1.1848 - val_accuracy: 0.4756
# Epoch 4/100
# 97/97 [==============================] - 14s 140ms/step - loss: 1.2044 - accuracy: 0.4481 - val_loss: 1.1446 - val_accuracy: 0.5088
# Epoch 5/100
# 97/97 [==============================] - 14s 140ms/step - loss: 1.1599 - accuracy: 0.4829 - val_loss: 1.0523 - val_accuracy: 0.5409
# Epoch 6/100
# 97/97 [==============================] - 13s 139ms/step - loss: 1.1268 - accuracy: 0.4989 - val_loss: 1.0709 - val_accuracy: 0.5049
# Epoch 7/100
# 97/97 [==============================] - 13s 138ms/step - loss: 1.0851 - accuracy: 0.5275 - val_loss: 1.0851 - val_accuracy: 0.5380
# Epoch 8/100
# 97/97 [==============================] - 14s 141ms/step - loss: 1.0411 - accuracy: 0.5421 - val_loss: 1.0205 - val_accuracy: 0.5448
# Epoch 9/100
# 97/97 [==============================] - 13s 139ms/step - loss: 1.0122 - accuracy: 0.5593 - val_loss: 1.0608 - val_accuracy: 0.5068
# Epoch 10/100
# 97/97 [==============================] - 13s 139ms/step - loss: 1.0118 - accuracy: 0.5675 - val_loss: 1.0562 - val_accuracy: 0.5253
# Epoch 11/100
# 97/97 [==============================] - 14s 140ms/step - loss: 1.0952 - accuracy: 0.5213 - val_loss: 1.0848 - val_accuracy: 0.5312
# Epoch 12/100
# 97/97 [==============================] - 14s 140ms/step - loss: 1.1199 - accuracy: 0.5050 - val_loss: 1.0486 - val_accuracy: 0.5702
# Epoch 13/100
# 97/97 [==============================] - 13s 139ms/step - loss: 1.0926 - accuracy: 0.5106 - val_loss: 1.0752 - val_accuracy: 0.5273
# Epoch 14/100
# 97/97 [==============================] - 14s 141ms/step - loss: 1.0651 - accuracy: 0.5330 - val_loss: 1.0187 - val_accuracy: 0.5858
# Epoch 15/100
# 97/97 [==============================] - 13s 139ms/step - loss: 1.0374 - accuracy: 0.5509 - val_loss: 1.0262 - val_accuracy: 0.5692
# Epoch 16/100
# 97/97 [==============================] - 13s 140ms/step - loss: 1.0093 - accuracy: 0.5593 - val_loss: 1.0171 - val_accuracy: 0.5858
# Epoch 17/100
# 97/97 [==============================] - 14s 140ms/step - loss: 1.0156 - accuracy: 0.5541 - val_loss: 1.0493 - val_accuracy: 0.5789
# Epoch 18/100
# 97/97 [==============================] - 13s 139ms/step - loss: 1.0037 - accuracy: 0.5720 - val_loss: 1.0351 - val_accuracy: 0.5653
# Epoch 19/100
# 97/97 [==============================] - 13s 139ms/step - loss: 1.0063 - accuracy: 0.5620 - val_loss: 1.0441 - val_accuracy: 0.5595
# Epoch 20/100
# 97/97 [==============================] - 13s 139ms/step - loss: 1.0336 - accuracy: 0.5528 - val_loss: 1.0648 - val_accuracy: 0.5731
# Epoch 21/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.9990 - accuracy: 0.5717 - val_loss: 1.0679 - val_accuracy: 0.5897
# Epoch 22/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.9769 - accuracy: 0.5909 - val_loss: 1.0523 - val_accuracy: 0.5848
# Epoch 23/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.9846 - accuracy: 0.5860 - val_loss: 1.0506 - val_accuracy: 0.5887
# Epoch 24/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.9532 - accuracy: 0.6049 - val_loss: 1.0592 - val_accuracy: 0.5897
# Epoch 25/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.9788 - accuracy: 0.5945 - val_loss: 1.1815 - val_accuracy: 0.5926
# Epoch 26/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.9495 - accuracy: 0.6042 - val_loss: 1.1976 - val_accuracy: 0.5867
# Epoch 27/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.9554 - accuracy: 0.6033 - val_loss: 1.0811 - val_accuracy: 0.5224
# Epoch 28/100
# 97/97 [==============================] - 14s 139ms/step - loss: 0.9352 - accuracy: 0.6306 - val_loss: 1.1152 - val_accuracy: 0.5819
# Epoch 29/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.9800 - accuracy: 0.5971 - val_loss: 1.0924 - val_accuracy: 0.5322
# Epoch 30/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.9307 - accuracy: 0.6351 - val_loss: 1.1648 - val_accuracy: 0.5848
# Epoch 31/100
# 97/97 [==============================] - 14s 141ms/step - loss: 0.9458 - accuracy: 0.6169 - val_loss: 1.2135 - val_accuracy: 0.5858
# Epoch 32/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.9139 - accuracy: 0.6407 - val_loss: 1.2948 - val_accuracy: 0.5780
# Epoch 33/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.9625 - accuracy: 0.6049 - val_loss: 1.1138 - val_accuracy: 0.5965
# Epoch 34/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8886 - accuracy: 0.6576 - val_loss: 1.1134 - val_accuracy: 0.5507
# Epoch 35/100
# 97/97 [==============================] - 14s 141ms/step - loss: 0.9184 - accuracy: 0.6351 - val_loss: 1.2561 - val_accuracy: 0.6033
# Epoch 36/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.9236 - accuracy: 0.6354 - val_loss: 1.4198 - val_accuracy: 0.5780
# Epoch 37/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.9200 - accuracy: 0.6280 - val_loss: 1.1055 - val_accuracy: 0.5819
# Epoch 38/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.8961 - accuracy: 0.6553 - val_loss: 1.3606 - val_accuracy: 0.5897
# Epoch 39/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8767 - accuracy: 0.6641 - val_loss: 1.1722 - val_accuracy: 0.5526
# Epoch 40/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8751 - accuracy: 0.6618 - val_loss: 1.1402 - val_accuracy: 0.5361
# Epoch 41/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.8739 - accuracy: 0.6631 - val_loss: 1.2542 - val_accuracy: 0.5770
# Epoch 42/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8701 - accuracy: 0.6660 - val_loss: 1.1780 - val_accuracy: 0.5029
# Epoch 43/100
# 97/97 [==============================] - 14s 141ms/step - loss: 0.8576 - accuracy: 0.6712 - val_loss: 1.3807 - val_accuracy: 0.5867
# Epoch 44/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8931 - accuracy: 0.6527 - val_loss: 1.1636 - val_accuracy: 0.5595
# Epoch 45/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8462 - accuracy: 0.6836 - val_loss: 1.1785 - val_accuracy: 0.5604
# Epoch 46/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8625 - accuracy: 0.6654 - val_loss: 1.4169 - val_accuracy: 0.5877
# Epoch 47/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8300 - accuracy: 0.6881 - val_loss: 1.3650 - val_accuracy: 0.5887
# Epoch 48/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.8603 - accuracy: 0.6696 - val_loss: 1.2326 - val_accuracy: 0.5780
# Epoch 49/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8295 - accuracy: 0.6888 - val_loss: 1.2811 - val_accuracy: 0.5692
# Epoch 50/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.8277 - accuracy: 0.6875 - val_loss: 1.1731 - val_accuracy: 0.5663
# Epoch 51/100
# 97/97 [==============================] - 14s 141ms/step - loss: 0.8409 - accuracy: 0.6719 - val_loss: 1.3144 - val_accuracy: 0.5721
# Epoch 52/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.7990 - accuracy: 0.6985 - val_loss: 1.1932 - val_accuracy: 0.5575
# Epoch 53/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8297 - accuracy: 0.6891 - val_loss: 1.1921 - val_accuracy: 0.5604
# Epoch 54/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.7910 - accuracy: 0.7031 - val_loss: 1.2291 - val_accuracy: 0.5507
# Epoch 55/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.8120 - accuracy: 0.6862 - val_loss: 1.5010 - val_accuracy: 0.5750
# Epoch 56/100
# 97/97 [==============================] - 13s 138ms/step - loss: 0.7936 - accuracy: 0.7015 - val_loss: 1.3242 - val_accuracy: 0.5799
# Epoch 57/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.7788 - accuracy: 0.7034 - val_loss: 1.5295 - val_accuracy: 0.5439
# Epoch 58/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.7471 - accuracy: 0.7197 - val_loss: 1.5197 - val_accuracy: 0.5936
# Epoch 59/100
# 97/97 [==============================] - 13s 139ms/step - loss: 0.7491 - accuracy: 0.7135 - val_loss: 1.5218 - val_accuracy: 0.5614
# Epoch 60/100
# 97/97 [==============================] - 14s 140ms/step - loss: 0.7505 - accuracy: 0.7141 - val_loss: 1.6338 - val_accuracy: 0.5624
# 33/33 [==============================] - 4s 108ms/step

# %%
vgg_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])
# Out:
# 33/33 [==============================] - 3s 101ms/step

# %%
# Val acc. and Val loss evolution
plot_acc_loss(vgg_model.fit)

# %%
# ROC curves
plot_ROC(vgg_model.predictions,basic_bundle.y_test_onehot,4)

# %%
# Confusion matrix
plot_cm(basic_bundle.y_test_onehot,vgg_model.predictions)

# %%
# Clasification report
print(classification_report(np.argmax(basic_bundle.y_test_onehot, axis=1), np.argmax(vgg_model.predictions, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       102
#            1       0.57      0.74      0.64       333
#            2       0.47      0.37      0.41       282
#            3       0.67      0.81      0.73       308
#
#     accuracy                           0.58      1025
#    macro avg       0.43      0.48      0.45      1025
# weighted avg       0.51      0.58      0.54      1025
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
