# %%
# Check RAM Memory

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
  
print(ram_gb)

# Login into drive

from google.colab import drive
drive.mount('/content/drive')

# Importing "load_model"

from keras.models import load_model
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# 89.63678208
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from tensorflow.keras import optimizers

# Download and import data preprocessing .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
from data_processing import data_bundle as data_bundle

# Download and import performance metrics .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
from performance_metrics import plot_ROC, plot_cm, plot_acc_loss
from sklearn.metrics import classification_report

# Download and import RN50 .py file
! wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/ResNet50.py
from ResNet50 import rn50_seei as rn50_class

# Download and import RN50 .py file
# Out:
# --2023-05-16 00:32:33--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5496 (5.4K) [text/plain]
# Saving to: ‘data_processing.py.1’
#
# data_processing.py. 100%[===================>]   5.37K  --.-KB/s    in 0s
#
# 2023-05-16 00:32:33 (34.9 MB/s) - ‘data_processing.py.1’ saved [5496/5496]
#
# --2023-05-16 00:32:33--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3235 (3.2K) [text/plain]
# Saving to: ‘performance_metrics.py.1’
#
# performance_metrics 100%[===================>]   3.16K  --.-KB/s    in 0s
#
# 2023-05-16 00:32:33 (9.11 MB/s) - ‘performance_metrics.py.1’ saved [3235/3235]
#
# --2023-05-16 00:32:33--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/ResNet50.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3313 (3.2K) [text/plain]
# Saving to: ‘ResNet50.py.1’
#
# ResNet50.py.1       100%[===================>]   3.24K  --.-KB/s    in 0s
#
# 2023-05-16 00:32:33 (63.2 MB/s) - ‘ResNet50.py.1’ saved [3313/3313]

# %%
# Define relevant paths for appropriately instantiating the data_bundle class
images_path_0 = "/content/drive/MyDrive/Thesis/M224A-0000/imageset_224_224.npy"
popn_path_0 = "/content/drive/MyDrive/Thesis/M224A-0000/popn_224A_0000.npy"
target_var = "gdp"

# In this case GDP has been chose
if target_var == "gdp":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-0000/gdp_224A_0000.npy"
  label_type = "GDPpercap"

elif target_var == "hdi":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-0000/hdi_224A_0000.npy"
  label_type = "HDI"

# Instantiate data_bundle object
basic_bundle = data_bundle(images_path_0, popn_path_0, labels_path_0, label_type, augmented=True)

# Preprocess data through the data_bundle class' methods
basic_bundle.normalize_images()
basic_bundle.normalize_popn()
basic_bundle.bundle_inputs()
basic_bundle.split_data(0.4,0.5,2023)
basic_bundle.augment_training_data()
basic_bundle.unbundle_and_shape_inputs()
basic_bundle.onehot_encode_labels()

# The resulting input sets are: self.X_tri, self.X_vai, self.X_tei (Images) and self.X_trp, self.X_vap, self.X_tep (Population)
# The resulting tragets are: self.y_train_onehot, self.y_val_onehot and self.y_test_onehot
# Where "self" is to be substituted by the given name to the data_bundle instance
# Out:
# /content/data_processing.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features = np.array(list(zip(self.images, np.array(self.popn))))
# /content/data_processing.py:66: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(i[0]), i[1], i[2]]))
# /content/data_processing.py:70: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(np.rot90(i[0])), i[1], i[2]]))
# /content/data_processing.py:74: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(np.rot90(np.rot90(i[0]))), i[1], i[2]]))
# /content/data_processing.py:79: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(i[0]), i[1], i[2]]))
# /content/data_processing.py:80: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(np.rot90(i[0])), i[1], i[2]]))
# /content/data_processing.py:81: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(np.rot90(np.rot90(i[0]))), i[1], i[2]]))
# /content/data_processing.py:82: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.fliplr(i[0]), i[1], i[2]]))
# /content/data_processing.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.flipud(i[0]), i[1], i[2]]))
# /content/data_processing.py:89: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented = np.array(augmented)

# %% [markdown]
# ### Model: ResNet50 - GDP per capita

# %%
# Eliminar learning rate de vgg.py y pasar el dropout a argumento de método y no de clase
rn_model = rn50_class(input_shape=(224, 224, 3))

rn_model.load_and_freeze_rn50()
rn_model.enable_dual_input()
rn_model.add_dense_layers(dropout_rate=0.00)
optimizer = sgd = optimizers.SGD(learning_rate=0.000075)
rn_model.define_and_compile_model(optimizer=optimizer)
rn_model.fit_model(train_in=[basic_bundle.X_tri, basic_bundle.X_trp], train_tar=basic_bundle.y_train_onehot, 
                    validation_in=[basic_bundle.X_vai, basic_bundle.X_vap], validation_tar=basic_bundle.y_val_onehot, 
                    batch_size=128, epochs=100, es_patience=33)

# Note: if model is on single mode train_in and validation_in should have just one "input" instead of a list of two "inputs"

rn_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])

# model Save/Load  

example_save_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"
example_load_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"

#vgg_model.save(<path_here>)
#vgg_model.load(<path_here>)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Epoch 1/100
# 58/58 [==============================] - 20s 130ms/step - loss: 1.3730 - accuracy: 0.2826 - val_loss: 1.3814 - val_accuracy: 0.2173
# Epoch 2/100
# 58/58 [==============================] - 4s 76ms/step - loss: 1.3611 - accuracy: 0.3068 - val_loss: 1.3656 - val_accuracy: 0.3528
# Epoch 3/100
# 58/58 [==============================] - 4s 76ms/step - loss: 1.3536 - accuracy: 0.3206 - val_loss: 1.3609 - val_accuracy: 0.3801
# Epoch 4/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.3494 - accuracy: 0.3212 - val_loss: 1.3651 - val_accuracy: 0.2895
# Epoch 5/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.3445 - accuracy: 0.3265 - val_loss: 1.3714 - val_accuracy: 0.3655
# Epoch 6/100
# 58/58 [==============================] - 4s 76ms/step - loss: 1.3406 - accuracy: 0.3217 - val_loss: 1.3550 - val_accuracy: 0.3860
# Epoch 7/100
# 58/58 [==============================] - 4s 77ms/step - loss: 1.3353 - accuracy: 0.3289 - val_loss: 1.3458 - val_accuracy: 0.3889
# Epoch 8/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.3326 - accuracy: 0.3364 - val_loss: 1.3504 - val_accuracy: 0.3216
# Epoch 9/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.3287 - accuracy: 0.3326 - val_loss: 1.3405 - val_accuracy: 0.3655
# Epoch 10/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.3259 - accuracy: 0.3339 - val_loss: 1.3462 - val_accuracy: 0.3684
# Epoch 11/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.3231 - accuracy: 0.3339 - val_loss: 1.3444 - val_accuracy: 0.2953
# Epoch 12/100
# 58/58 [==============================] - 4s 75ms/step - loss: 1.3204 - accuracy: 0.3342 - val_loss: 1.3492 - val_accuracy: 0.3899
# Epoch 13/100
# 58/58 [==============================] - 4s 76ms/step - loss: 1.3177 - accuracy: 0.3304 - val_loss: 1.3303 - val_accuracy: 0.3938
# Epoch 14/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.3152 - accuracy: 0.3318 - val_loss: 1.3338 - val_accuracy: 0.2992
# Epoch 15/100
# 58/58 [==============================] - 4s 76ms/step - loss: 1.3125 - accuracy: 0.3349 - val_loss: 1.3187 - val_accuracy: 0.3977
# Epoch 16/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.3089 - accuracy: 0.3347 - val_loss: 1.3364 - val_accuracy: 0.2934
# Epoch 17/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.3022 - accuracy: 0.3263 - val_loss: 1.3136 - val_accuracy: 0.3918
# Epoch 18/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2906 - accuracy: 0.3360 - val_loss: 1.3162 - val_accuracy: 0.3119
# Epoch 19/100
# 58/58 [==============================] - 4s 75ms/step - loss: 1.2850 - accuracy: 0.3456 - val_loss: 1.3006 - val_accuracy: 0.4162
# Epoch 20/100
# 58/58 [==============================] - 4s 75ms/step - loss: 1.2803 - accuracy: 0.3403 - val_loss: 1.3051 - val_accuracy: 0.4220
# Epoch 21/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2766 - accuracy: 0.3517 - val_loss: 1.2998 - val_accuracy: 0.4064
# Epoch 22/100
# 58/58 [==============================] - 4s 76ms/step - loss: 1.2745 - accuracy: 0.3493 - val_loss: 1.2949 - val_accuracy: 0.4230
# Epoch 23/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2685 - accuracy: 0.3578 - val_loss: 1.2958 - val_accuracy: 0.4094
# Epoch 24/100
# 58/58 [==============================] - 4s 75ms/step - loss: 1.2656 - accuracy: 0.3562 - val_loss: 1.2867 - val_accuracy: 0.4288
# Epoch 25/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2636 - accuracy: 0.3638 - val_loss: 1.2773 - val_accuracy: 0.3908
# Epoch 26/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2597 - accuracy: 0.3703 - val_loss: 1.3049 - val_accuracy: 0.3889
# Epoch 27/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2559 - accuracy: 0.3737 - val_loss: 1.2723 - val_accuracy: 0.4181
# Epoch 28/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.2527 - accuracy: 0.3733 - val_loss: 1.2707 - val_accuracy: 0.4074
# Epoch 29/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2499 - accuracy: 0.3801 - val_loss: 1.2713 - val_accuracy: 0.4152
# Epoch 30/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2476 - accuracy: 0.3855 - val_loss: 1.2565 - val_accuracy: 0.4288
# Epoch 31/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.2448 - accuracy: 0.3725 - val_loss: 1.2738 - val_accuracy: 0.3626
# Epoch 32/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.2429 - accuracy: 0.3924 - val_loss: 1.2563 - val_accuracy: 0.4191
# Epoch 33/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.2398 - accuracy: 0.3867 - val_loss: 1.2621 - val_accuracy: 0.4279
# Epoch 34/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2365 - accuracy: 0.4014 - val_loss: 1.2574 - val_accuracy: 0.4162
# Epoch 35/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.2339 - accuracy: 0.3938 - val_loss: 1.2606 - val_accuracy: 0.4133
# Epoch 36/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.2331 - accuracy: 0.3967 - val_loss: 1.2538 - val_accuracy: 0.3879
# Epoch 37/100
# 58/58 [==============================] - 4s 75ms/step - loss: 1.2301 - accuracy: 0.4016 - val_loss: 1.2403 - val_accuracy: 0.4347
# Epoch 38/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2246 - accuracy: 0.3938 - val_loss: 1.2833 - val_accuracy: 0.4006
# Epoch 39/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2244 - accuracy: 0.4130 - val_loss: 1.2493 - val_accuracy: 0.4123
# Epoch 40/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.2219 - accuracy: 0.3984 - val_loss: 1.2288 - val_accuracy: 0.4308
# Epoch 41/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2180 - accuracy: 0.3938 - val_loss: 1.2416 - val_accuracy: 0.3499
# Epoch 42/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2196 - accuracy: 0.4081 - val_loss: 1.2559 - val_accuracy: 0.3752
# Epoch 43/100
# 58/58 [==============================] - 4s 76ms/step - loss: 1.2166 - accuracy: 0.4123 - val_loss: 1.2355 - val_accuracy: 0.4357
# Epoch 44/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.2146 - accuracy: 0.4130 - val_loss: 1.2377 - val_accuracy: 0.4308
# Epoch 45/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2137 - accuracy: 0.4115 - val_loss: 1.2266 - val_accuracy: 0.4025
# Epoch 46/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.2109 - accuracy: 0.4218 - val_loss: 1.2374 - val_accuracy: 0.4327
# Epoch 47/100
# 58/58 [==============================] - 4s 76ms/step - loss: 1.2099 - accuracy: 0.4113 - val_loss: 1.2438 - val_accuracy: 0.4376
# Epoch 48/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.2090 - accuracy: 0.4168 - val_loss: 1.2207 - val_accuracy: 0.4162
# Epoch 49/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.2077 - accuracy: 0.4247 - val_loss: 1.2372 - val_accuracy: 0.4298
# Epoch 50/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2056 - accuracy: 0.4220 - val_loss: 1.2234 - val_accuracy: 0.4279
# Epoch 51/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.2047 - accuracy: 0.4128 - val_loss: 1.2316 - val_accuracy: 0.3363
# Epoch 52/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2030 - accuracy: 0.4243 - val_loss: 1.2358 - val_accuracy: 0.4357
# Epoch 53/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.2012 - accuracy: 0.4167 - val_loss: 1.2463 - val_accuracy: 0.4152
# Epoch 54/100
# 58/58 [==============================] - 4s 76ms/step - loss: 1.1987 - accuracy: 0.4313 - val_loss: 1.2090 - val_accuracy: 0.4454
# Epoch 55/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1998 - accuracy: 0.4308 - val_loss: 1.2141 - val_accuracy: 0.4405
# Epoch 56/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1986 - accuracy: 0.4281 - val_loss: 1.2154 - val_accuracy: 0.3743
# Epoch 57/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1992 - accuracy: 0.4282 - val_loss: 1.2292 - val_accuracy: 0.3957
# Epoch 58/100
# 58/58 [==============================] - 4s 77ms/step - loss: 1.1954 - accuracy: 0.4368 - val_loss: 1.2241 - val_accuracy: 0.4522
# Epoch 59/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.1945 - accuracy: 0.4339 - val_loss: 1.2116 - val_accuracy: 0.4211
# Epoch 60/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1945 - accuracy: 0.4292 - val_loss: 1.2146 - val_accuracy: 0.3723
# Epoch 61/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1918 - accuracy: 0.4350 - val_loss: 1.2113 - val_accuracy: 0.4045
# Epoch 62/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1913 - accuracy: 0.4365 - val_loss: 1.2039 - val_accuracy: 0.4474
# Epoch 63/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.1893 - accuracy: 0.4381 - val_loss: 1.2137 - val_accuracy: 0.4415
# Epoch 64/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.1907 - accuracy: 0.4326 - val_loss: 1.2309 - val_accuracy: 0.4337
# Epoch 65/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1873 - accuracy: 0.4323 - val_loss: 1.2063 - val_accuracy: 0.4327
# Epoch 66/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1861 - accuracy: 0.4379 - val_loss: 1.2299 - val_accuracy: 0.3743
# Epoch 67/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1865 - accuracy: 0.4391 - val_loss: 1.2316 - val_accuracy: 0.4074
# Epoch 68/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.1862 - accuracy: 0.4425 - val_loss: 1.2075 - val_accuracy: 0.4133
# Epoch 69/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1853 - accuracy: 0.4414 - val_loss: 1.2183 - val_accuracy: 0.4211
# Epoch 70/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1838 - accuracy: 0.4400 - val_loss: 1.1857 - val_accuracy: 0.4493
# Epoch 71/100
# 58/58 [==============================] - 4s 72ms/step - loss: 1.1833 - accuracy: 0.4376 - val_loss: 1.2037 - val_accuracy: 0.4318
# Epoch 72/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1821 - accuracy: 0.4440 - val_loss: 1.1997 - val_accuracy: 0.4396
# Epoch 73/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1810 - accuracy: 0.4448 - val_loss: 1.2189 - val_accuracy: 0.4308
# Epoch 74/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1804 - accuracy: 0.4431 - val_loss: 1.1920 - val_accuracy: 0.4474
# Epoch 75/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1797 - accuracy: 0.4475 - val_loss: 1.2020 - val_accuracy: 0.3928
# Epoch 76/100
# 58/58 [==============================] - 4s 76ms/step - loss: 1.1794 - accuracy: 0.4358 - val_loss: 1.1860 - val_accuracy: 0.4561
# Epoch 77/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1780 - accuracy: 0.4415 - val_loss: 1.2016 - val_accuracy: 0.4045
# Epoch 78/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1772 - accuracy: 0.4461 - val_loss: 1.1970 - val_accuracy: 0.4474
# Epoch 79/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1776 - accuracy: 0.4478 - val_loss: 1.1982 - val_accuracy: 0.3967
# Epoch 80/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1785 - accuracy: 0.4426 - val_loss: 1.2031 - val_accuracy: 0.4016
# Epoch 81/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1753 - accuracy: 0.4472 - val_loss: 1.2177 - val_accuracy: 0.3782
# Epoch 82/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1754 - accuracy: 0.4392 - val_loss: 1.1992 - val_accuracy: 0.3996
# Epoch 83/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1747 - accuracy: 0.4499 - val_loss: 1.2044 - val_accuracy: 0.3811
# Epoch 84/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1725 - accuracy: 0.4419 - val_loss: 1.2084 - val_accuracy: 0.4298
# Epoch 85/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1744 - accuracy: 0.4459 - val_loss: 1.2160 - val_accuracy: 0.3665
# Epoch 86/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1736 - accuracy: 0.4445 - val_loss: 1.2081 - val_accuracy: 0.3587
# Epoch 87/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1719 - accuracy: 0.4430 - val_loss: 1.1941 - val_accuracy: 0.4123
# Epoch 88/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1712 - accuracy: 0.4441 - val_loss: 1.1922 - val_accuracy: 0.4298
# Epoch 89/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1706 - accuracy: 0.4441 - val_loss: 1.1933 - val_accuracy: 0.4094
# Epoch 90/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1704 - accuracy: 0.4482 - val_loss: 1.1983 - val_accuracy: 0.4035
# Epoch 91/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1700 - accuracy: 0.4419 - val_loss: 1.2020 - val_accuracy: 0.3947
# Epoch 92/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1687 - accuracy: 0.4463 - val_loss: 1.1971 - val_accuracy: 0.4025
# Epoch 93/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1689 - accuracy: 0.4501 - val_loss: 1.1934 - val_accuracy: 0.4152
# Epoch 94/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1673 - accuracy: 0.4474 - val_loss: 1.2014 - val_accuracy: 0.3928
# Epoch 95/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1673 - accuracy: 0.4468 - val_loss: 1.1858 - val_accuracy: 0.4191
# Epoch 96/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1673 - accuracy: 0.4441 - val_loss: 1.1889 - val_accuracy: 0.4357
# Epoch 97/100
# 58/58 [==============================] - 4s 74ms/step - loss: 1.1666 - accuracy: 0.4503 - val_loss: 1.1923 - val_accuracy: 0.4220
# Epoch 98/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1668 - accuracy: 0.4446 - val_loss: 1.1978 - val_accuracy: 0.3830
# Epoch 99/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1653 - accuracy: 0.4499 - val_loss: 1.1882 - val_accuracy: 0.4298
# Epoch 100/100
# 58/58 [==============================] - 4s 73ms/step - loss: 1.1651 - accuracy: 0.4469 - val_loss: 1.2142 - val_accuracy: 0.4006
# 33/33 [==============================] - 2s 24ms/step

# %%
rn_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])
# Out:
# 33/33 [==============================] - 1s 18ms/step

# %%
# Val acc. and Val loss evolution
plot_acc_loss(rn_model.fit)

# %%
# ROC curves
plot_ROC(rn_model.predictions,basic_bundle.y_test_onehot,4)

# %%
# Confusion matrix
plot_cm(basic_bundle.y_test_onehot,rn_model.predictions)

# %%
# Clasification report
print(classification_report(np.argmax(basic_bundle.y_test_onehot, axis=1), np.argmax(rn_model.predictions, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.64      0.44       102
#            1       0.41      0.44      0.43       333
#            2       0.25      0.01      0.03       282
#            3       0.47      0.70      0.56       308
#
#     accuracy                           0.42      1025
#    macro avg       0.37      0.45      0.36      1025
# weighted avg       0.38      0.42      0.36      1025

# %%
rn_model.save("/content/drive/MyDrive/Thesis/M224A-0000/rn50_gdp_224A_0000_v1.h5")
