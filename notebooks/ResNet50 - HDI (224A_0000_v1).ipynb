# %%
# Check RAM Memory

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
  
print(ram_gb)

# Login into drive

from google.colab import drive
drive.mount('/content/drive')

# Importing "load_model"

from keras.models import load_model
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# 89.63678208
# Mounted at /content/drive

# %%
import numpy as np
from tensorflow.keras import optimizers

# Download and import data preprocessing .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
from data_processing import data_bundle as data_bundle

# Download and import performance metrics .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
from performance_metrics import plot_ROC, plot_cm, plot_acc_loss
from sklearn.metrics import classification_report

# Download and import RN50 .py file
! wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/ResNet50.py
from ResNet50 import rn50_seei as rn50_class

# Download and import RN50 .py file
# Out:
# --2023-05-15 23:47:54--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5496 (5.4K) [text/plain]
# Saving to: ‘data_processing.py’
#
# data_processing.py  100%[===================>]   5.37K  --.-KB/s    in 0s
#
# 2023-05-15 23:47:54 (73.2 MB/s) - ‘data_processing.py’ saved [5496/5496]
#
# --2023-05-15 23:47:54--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3235 (3.2K) [text/plain]
# Saving to: ‘performance_metrics.py’
#
# performance_metrics 100%[===================>]   3.16K  --.-KB/s    in 0s
#
# 2023-05-15 23:47:55 (64.7 MB/s) - ‘performance_metrics.py’ saved [3235/3235]
#
# --2023-05-15 23:47:55--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/ResNet50.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3313 (3.2K) [text/plain]
# Saving to: ‘ResNet50.py’
#
# ResNet50.py         100%[===================>]   3.24K  --.-KB/s    in 0s
#
# 2023-05-15 23:47:55 (53.3 MB/s) - ‘ResNet50.py’ saved [3313/3313]

# %%
# Define relevant paths for appropriately instantiating the data_bundle class
images_path_0 = "/content/drive/MyDrive/Thesis/M224A-0000/imageset_224_224.npy"
popn_path_0 = "/content/drive/MyDrive/Thesis/M224A-0000/popn_224A_0000.npy"
target_var = "hdi"

# In this case GDP has been chose
if target_var == "gdp":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-0000/gdp_224A_0000.npy"
  label_type = "GDPpercap"

elif target_var == "hdi":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-0000/hdi_224A_0000.npy"
  label_type = "HDI"

# Instantiate data_bundle object
basic_bundle = data_bundle(images_path_0, popn_path_0, labels_path_0, label_type, augmented=True)

# Preprocess data through the data_bundle class' methods
basic_bundle.normalize_images()
basic_bundle.normalize_popn()
basic_bundle.bundle_inputs()
basic_bundle.split_data(0.4,0.5,2023)
basic_bundle.augment_training_data()
basic_bundle.unbundle_and_shape_inputs()
basic_bundle.onehot_encode_labels()

# The resulting input sets are: self.X_tri, self.X_vai, self.X_tei (Images) and self.X_trp, self.X_vap, self.X_tep (Population)
# The resulting tragets are: self.y_train_onehot, self.y_val_onehot and self.y_test_onehot
# Where "self" is to be substituted by the given name to the data_bundle instance
# Out:
# /content/data_processing.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features = np.array(list(zip(self.images, np.array(self.popn))))
# /content/data_processing.py:66: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(i[0]), i[1], i[2]]))
# /content/data_processing.py:70: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(np.rot90(i[0])), i[1], i[2]]))
# /content/data_processing.py:79: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(i[0]), i[1], i[2]]))
# /content/data_processing.py:80: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(np.rot90(i[0])), i[1], i[2]]))
# /content/data_processing.py:81: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(np.rot90(np.rot90(i[0]))), i[1], i[2]]))
# /content/data_processing.py:82: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.fliplr(i[0]), i[1], i[2]]))
# /content/data_processing.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.flipud(i[0]), i[1], i[2]]))
# /content/data_processing.py:74: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented.append(np.array([np.rot90(np.rot90(np.rot90(i[0]))), i[1], i[2]]))
# /content/data_processing.py:89: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   augmented = np.array(augmented)

# %% [markdown]
# ### Model: ResNet50 - HDI

# %%
# Eliminar learning rate de vgg.py y pasar el dropout a argumento de método y no de clase
rn_model = rn50_class(input_shape=(224, 224, 3))

rn_model.load_and_freeze_rn50()
rn_model.enable_dual_input()
rn_model.add_dense_layers(dropout_rate=0.00)
optimizer = sgd = optimizers.SGD(learning_rate=0.000075)
rn_model.define_and_compile_model(optimizer=optimizer)
rn_model.fit_model(train_in=[basic_bundle.X_tri, basic_bundle.X_trp], train_tar=basic_bundle.y_train_onehot, 
                    validation_in=[basic_bundle.X_vai, basic_bundle.X_vap], validation_tar=basic_bundle.y_val_onehot, 
                    batch_size=128, epochs=250, es_patience=33)

# Note: if model is on single mode train_in and validation_in should have just one "input" instead of a list of two "inputs"

rn_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])

# model Save/Load  

example_save_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"
example_load_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"

#vgg_model.save(<path_here>)
#vgg_model.load(<path_here>)
# Out:
# Epoch 1/250
# 59/59 [==============================] - 10s 108ms/step - loss: 1.3822 - accuracy: 0.3190 - val_loss: 1.3768 - val_accuracy: 0.3616
# Epoch 2/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.3678 - accuracy: 0.3812 - val_loss: 1.3946 - val_accuracy: 0.2232
# Epoch 3/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.3619 - accuracy: 0.3885 - val_loss: 1.3837 - val_accuracy: 0.3645
# Epoch 4/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.3529 - accuracy: 0.3986 - val_loss: 1.3661 - val_accuracy: 0.3080
# Epoch 5/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.3529 - accuracy: 0.4061 - val_loss: 1.3809 - val_accuracy: 0.2632
# Epoch 6/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.3428 - accuracy: 0.4203 - val_loss: 1.4044 - val_accuracy: 0.1832
# Epoch 7/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.3402 - accuracy: 0.4115 - val_loss: 1.3649 - val_accuracy: 0.3363
# Epoch 8/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.3339 - accuracy: 0.4324 - val_loss: 1.3968 - val_accuracy: 0.2261
# Epoch 9/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.3289 - accuracy: 0.4183 - val_loss: 1.3675 - val_accuracy: 0.3499
# Epoch 10/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.3230 - accuracy: 0.4243 - val_loss: 1.4048 - val_accuracy: 0.3635
# Epoch 11/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.3192 - accuracy: 0.4310 - val_loss: 1.3782 - val_accuracy: 0.3548
# Epoch 12/250
# 59/59 [==============================] - 4s 71ms/step - loss: 1.3152 - accuracy: 0.4315 - val_loss: 1.3437 - val_accuracy: 0.3519
# Epoch 13/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.3118 - accuracy: 0.4267 - val_loss: 1.3545 - val_accuracy: 0.3333
# Epoch 14/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.3081 - accuracy: 0.4331 - val_loss: 1.3748 - val_accuracy: 0.3421
# Epoch 15/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.3013 - accuracy: 0.4366 - val_loss: 1.3517 - val_accuracy: 0.3304
# Epoch 16/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.2991 - accuracy: 0.4338 - val_loss: 1.3493 - val_accuracy: 0.3363
# Epoch 17/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.2879 - accuracy: 0.4368 - val_loss: 1.3043 - val_accuracy: 0.3626
# Epoch 18/250
# 59/59 [==============================] - 4s 74ms/step - loss: 1.2613 - accuracy: 0.4236 - val_loss: 1.3756 - val_accuracy: 0.2300
# Epoch 19/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.2478 - accuracy: 0.4223 - val_loss: 1.2685 - val_accuracy: 0.3821
# Epoch 20/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.2339 - accuracy: 0.4388 - val_loss: 1.2938 - val_accuracy: 0.3674
# Epoch 21/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.2187 - accuracy: 0.4437 - val_loss: 1.2605 - val_accuracy: 0.3431
# Epoch 22/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.2106 - accuracy: 0.4499 - val_loss: 1.2713 - val_accuracy: 0.3635
# Epoch 23/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.2006 - accuracy: 0.4437 - val_loss: 1.2369 - val_accuracy: 0.3509
# Epoch 24/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1960 - accuracy: 0.4495 - val_loss: 1.2832 - val_accuracy: 0.3704
# Epoch 25/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1860 - accuracy: 0.4529 - val_loss: 1.2720 - val_accuracy: 0.3558
# Epoch 26/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1802 - accuracy: 0.4529 - val_loss: 1.3234 - val_accuracy: 0.3236
# Epoch 27/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1730 - accuracy: 0.4565 - val_loss: 1.2079 - val_accuracy: 0.3733
# Epoch 28/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1711 - accuracy: 0.4580 - val_loss: 1.2463 - val_accuracy: 0.3665
# Epoch 29/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1663 - accuracy: 0.4516 - val_loss: 1.2687 - val_accuracy: 0.3519
# Epoch 30/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1581 - accuracy: 0.4606 - val_loss: 1.2593 - val_accuracy: 0.3596
# Epoch 31/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1530 - accuracy: 0.4626 - val_loss: 1.1967 - val_accuracy: 0.3665
# Epoch 32/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1508 - accuracy: 0.4678 - val_loss: 1.2402 - val_accuracy: 0.3382
# Epoch 33/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.1464 - accuracy: 0.4629 - val_loss: 1.2103 - val_accuracy: 0.3986
# Epoch 34/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1455 - accuracy: 0.4711 - val_loss: 1.2244 - val_accuracy: 0.3938
# Epoch 35/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1411 - accuracy: 0.4674 - val_loss: 1.1983 - val_accuracy: 0.3713
# Epoch 36/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1402 - accuracy: 0.4612 - val_loss: 1.2418 - val_accuracy: 0.3743
# Epoch 37/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1362 - accuracy: 0.4618 - val_loss: 1.1728 - val_accuracy: 0.3908
# Epoch 38/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1332 - accuracy: 0.4718 - val_loss: 1.2328 - val_accuracy: 0.3830
# Epoch 39/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1299 - accuracy: 0.4731 - val_loss: 1.2092 - val_accuracy: 0.3723
# Epoch 40/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1276 - accuracy: 0.4735 - val_loss: 1.2178 - val_accuracy: 0.3489
# Epoch 41/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1270 - accuracy: 0.4640 - val_loss: 1.2528 - val_accuracy: 0.3723
# Epoch 42/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1229 - accuracy: 0.4754 - val_loss: 1.1978 - val_accuracy: 0.3762
# Epoch 43/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1234 - accuracy: 0.4699 - val_loss: 1.2385 - val_accuracy: 0.3723
# Epoch 44/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1220 - accuracy: 0.4766 - val_loss: 1.2447 - val_accuracy: 0.3567
# Epoch 45/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1212 - accuracy: 0.4758 - val_loss: 1.2199 - val_accuracy: 0.3850
# Epoch 46/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.1159 - accuracy: 0.4714 - val_loss: 1.1840 - val_accuracy: 0.4055
# Epoch 47/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1164 - accuracy: 0.4822 - val_loss: 1.2080 - val_accuracy: 0.3655
# Epoch 48/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1173 - accuracy: 0.4698 - val_loss: 1.2031 - val_accuracy: 0.3752
# Epoch 49/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1134 - accuracy: 0.4757 - val_loss: 1.2050 - val_accuracy: 0.3938
# Epoch 50/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1135 - accuracy: 0.4781 - val_loss: 1.2003 - val_accuracy: 0.3967
# Epoch 51/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1100 - accuracy: 0.4790 - val_loss: 1.1507 - val_accuracy: 0.4045
# Epoch 52/250
# 59/59 [==============================] - 4s 75ms/step - loss: 1.1101 - accuracy: 0.4826 - val_loss: 1.1791 - val_accuracy: 0.4064
# Epoch 53/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1068 - accuracy: 0.4765 - val_loss: 1.1719 - val_accuracy: 0.3762
# Epoch 54/250
# 59/59 [==============================] - 4s 74ms/step - loss: 1.1081 - accuracy: 0.4807 - val_loss: 1.2091 - val_accuracy: 0.3713
# Epoch 55/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1072 - accuracy: 0.4754 - val_loss: 1.2525 - val_accuracy: 0.3694
# Epoch 56/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1037 - accuracy: 0.4827 - val_loss: 1.1761 - val_accuracy: 0.3772
# Epoch 57/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1037 - accuracy: 0.4860 - val_loss: 1.2069 - val_accuracy: 0.3860
# Epoch 58/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.1029 - accuracy: 0.4796 - val_loss: 1.1620 - val_accuracy: 0.4094
# Epoch 59/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1010 - accuracy: 0.4839 - val_loss: 1.1859 - val_accuracy: 0.4084
# Epoch 60/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.1020 - accuracy: 0.4859 - val_loss: 1.1613 - val_accuracy: 0.4181
# Epoch 61/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.0992 - accuracy: 0.4880 - val_loss: 1.1555 - val_accuracy: 0.4279
# Epoch 62/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.1004 - accuracy: 0.4842 - val_loss: 1.1833 - val_accuracy: 0.4084
# Epoch 63/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.1001 - accuracy: 0.4894 - val_loss: 1.1468 - val_accuracy: 0.4162
# Epoch 64/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0982 - accuracy: 0.4880 - val_loss: 1.1931 - val_accuracy: 0.3801
# Epoch 65/250
# 59/59 [==============================] - 5s 77ms/step - loss: 1.0982 - accuracy: 0.4828 - val_loss: 1.1411 - val_accuracy: 0.4347
# Epoch 66/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.0961 - accuracy: 0.4883 - val_loss: 1.1389 - val_accuracy: 0.4405
# Epoch 67/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0970 - accuracy: 0.4864 - val_loss: 1.1516 - val_accuracy: 0.4133
# Epoch 68/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0949 - accuracy: 0.4926 - val_loss: 1.1517 - val_accuracy: 0.4220
# Epoch 69/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0954 - accuracy: 0.4940 - val_loss: 1.1615 - val_accuracy: 0.4133
# Epoch 70/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0941 - accuracy: 0.4875 - val_loss: 1.1490 - val_accuracy: 0.4211
# Epoch 71/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0905 - accuracy: 0.4919 - val_loss: 1.1435 - val_accuracy: 0.4230
# Epoch 72/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0924 - accuracy: 0.4847 - val_loss: 1.1639 - val_accuracy: 0.4123
# Epoch 73/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0907 - accuracy: 0.4932 - val_loss: 1.1724 - val_accuracy: 0.3967
# Epoch 74/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0898 - accuracy: 0.4880 - val_loss: 1.1880 - val_accuracy: 0.3752
# Epoch 75/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0894 - accuracy: 0.4924 - val_loss: 1.1519 - val_accuracy: 0.4240
# Epoch 76/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0890 - accuracy: 0.4858 - val_loss: 1.1636 - val_accuracy: 0.4152
# Epoch 77/250
# 59/59 [==============================] - 4s 74ms/step - loss: 1.0885 - accuracy: 0.4879 - val_loss: 1.1417 - val_accuracy: 0.4191
# Epoch 78/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0867 - accuracy: 0.4907 - val_loss: 1.1559 - val_accuracy: 0.4211
# Epoch 79/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0860 - accuracy: 0.4952 - val_loss: 1.1409 - val_accuracy: 0.4279
# Epoch 80/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0861 - accuracy: 0.4914 - val_loss: 1.1663 - val_accuracy: 0.4055
# Epoch 81/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0843 - accuracy: 0.4964 - val_loss: 1.1816 - val_accuracy: 0.4094
# Epoch 82/250
# 59/59 [==============================] - 4s 74ms/step - loss: 1.0870 - accuracy: 0.4831 - val_loss: 1.1858 - val_accuracy: 0.4025
# Epoch 83/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0845 - accuracy: 0.4899 - val_loss: 1.1514 - val_accuracy: 0.4201
# Epoch 84/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0832 - accuracy: 0.4945 - val_loss: 1.1577 - val_accuracy: 0.4162
# Epoch 85/250
# 59/59 [==============================] - 4s 74ms/step - loss: 1.0834 - accuracy: 0.4928 - val_loss: 1.1459 - val_accuracy: 0.4142
# Epoch 86/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0860 - accuracy: 0.4920 - val_loss: 1.1783 - val_accuracy: 0.4084
# Epoch 87/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0836 - accuracy: 0.4969 - val_loss: 1.1488 - val_accuracy: 0.4133
# Epoch 88/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0833 - accuracy: 0.4967 - val_loss: 1.1500 - val_accuracy: 0.4103
# Epoch 89/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.0816 - accuracy: 0.4967 - val_loss: 1.1244 - val_accuracy: 0.4513
# Epoch 90/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0823 - accuracy: 0.4967 - val_loss: 1.2118 - val_accuracy: 0.3996
# Epoch 91/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0818 - accuracy: 0.4948 - val_loss: 1.1745 - val_accuracy: 0.4113
# Epoch 92/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.0808 - accuracy: 0.4961 - val_loss: 1.1249 - val_accuracy: 0.4561
# Epoch 93/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0803 - accuracy: 0.4963 - val_loss: 1.1767 - val_accuracy: 0.3723
# Epoch 94/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0784 - accuracy: 0.4981 - val_loss: 1.1480 - val_accuracy: 0.4162
# Epoch 95/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0784 - accuracy: 0.5000 - val_loss: 1.1357 - val_accuracy: 0.4269
# Epoch 96/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0800 - accuracy: 0.4991 - val_loss: 1.1490 - val_accuracy: 0.4269
# Epoch 97/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0778 - accuracy: 0.4984 - val_loss: 1.2024 - val_accuracy: 0.4064
# Epoch 98/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0799 - accuracy: 0.4955 - val_loss: 1.1400 - val_accuracy: 0.4259
# Epoch 99/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0768 - accuracy: 0.4935 - val_loss: 1.1340 - val_accuracy: 0.4298
# Epoch 100/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0760 - accuracy: 0.5009 - val_loss: 1.1415 - val_accuracy: 0.4308
# Epoch 101/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0771 - accuracy: 0.4989 - val_loss: 1.1278 - val_accuracy: 0.4269
# Epoch 102/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0777 - accuracy: 0.4979 - val_loss: 1.1231 - val_accuracy: 0.4503
# Epoch 103/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0768 - accuracy: 0.5007 - val_loss: 1.1849 - val_accuracy: 0.4084
# Epoch 104/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0744 - accuracy: 0.5043 - val_loss: 1.1474 - val_accuracy: 0.4308
# Epoch 105/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0759 - accuracy: 0.5008 - val_loss: 1.1612 - val_accuracy: 0.4172
# Epoch 106/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0755 - accuracy: 0.4973 - val_loss: 1.1677 - val_accuracy: 0.3899
# Epoch 107/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0737 - accuracy: 0.5019 - val_loss: 1.1292 - val_accuracy: 0.4327
# Epoch 108/250
# 59/59 [==============================] - 4s 71ms/step - loss: 1.0733 - accuracy: 0.4984 - val_loss: 1.1804 - val_accuracy: 0.4084
# Epoch 109/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0722 - accuracy: 0.5013 - val_loss: 1.1392 - val_accuracy: 0.4103
# Epoch 110/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0715 - accuracy: 0.5011 - val_loss: 1.1612 - val_accuracy: 0.4211
# Epoch 111/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0714 - accuracy: 0.4971 - val_loss: 1.1349 - val_accuracy: 0.4298
# Epoch 112/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0722 - accuracy: 0.4980 - val_loss: 1.1515 - val_accuracy: 0.4211
# Epoch 113/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0714 - accuracy: 0.5027 - val_loss: 1.1241 - val_accuracy: 0.4366
# Epoch 114/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0712 - accuracy: 0.4973 - val_loss: 1.1365 - val_accuracy: 0.4298
# Epoch 115/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0706 - accuracy: 0.5035 - val_loss: 1.1640 - val_accuracy: 0.4113
# Epoch 116/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0691 - accuracy: 0.5065 - val_loss: 1.1287 - val_accuracy: 0.4347
# Epoch 117/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0706 - accuracy: 0.5024 - val_loss: 1.1230 - val_accuracy: 0.4347
# Epoch 118/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0711 - accuracy: 0.5072 - val_loss: 1.1764 - val_accuracy: 0.4123
# Epoch 119/250
# 59/59 [==============================] - 4s 74ms/step - loss: 1.0701 - accuracy: 0.5039 - val_loss: 1.1375 - val_accuracy: 0.4337
# Epoch 120/250
# 59/59 [==============================] - 4s 73ms/step - loss: 1.0680 - accuracy: 0.5023 - val_loss: 1.1305 - val_accuracy: 0.4123
# Epoch 121/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0696 - accuracy: 0.5052 - val_loss: 1.1304 - val_accuracy: 0.4250
# Epoch 122/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0672 - accuracy: 0.5036 - val_loss: 1.1346 - val_accuracy: 0.4211
# Epoch 123/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0682 - accuracy: 0.5036 - val_loss: 1.1305 - val_accuracy: 0.4337
# Epoch 124/250
# 59/59 [==============================] - 4s 72ms/step - loss: 1.0660 - accuracy: 0.5072 - val_loss: 1.1293 - val_accuracy: 0.4347
# Epoch 125/250
# 59/59 [==============================] - 4s 76ms/step - loss: 1.0676 - accuracy: 0.5020 - val_loss: 1.1429 - val_accuracy: 0.4230
# 33/33 [==============================] - 1s 17ms/step

# %%
rn_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])
# Out:
# 33/33 [==============================] - 1s 17ms/step

# %%
# Val acc. and Val loss evolution
plot_acc_loss(rn_model.fit)

# %%
# ROC curves
plot_ROC(rn_model.predictions,basic_bundle.y_test_onehot,4)

# %%
# Confusion matrix
plot_cm(basic_bundle.y_test_onehot,rn_model.predictions)

# %%
# Clasification report
print(classification_report(np.argmax(basic_bundle.y_test_onehot, axis=1), np.argmax(rn_model.predictions, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.71      0.51       114
#            1       0.45      0.21      0.28       270
#            2       0.40      0.43      0.42       316
#            3       0.56      0.62      0.59       325
#
#     accuracy                           0.46      1025
#    macro avg       0.45      0.49      0.45      1025
# weighted avg       0.47      0.46      0.45      1025

# %%
# 0.5

# %%
rn_model.save("/content/drive/MyDrive/Thesis/M224A-0000/rn50_hdi_224A_0000_v1.h5")
