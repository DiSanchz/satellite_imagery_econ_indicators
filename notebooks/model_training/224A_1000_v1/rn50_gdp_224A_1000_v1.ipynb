# %%
# Check RAM Memory

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
  
print(ram_gb)

# Login into drive

from google.colab import drive
drive.mount('/content/drive')

# Importing "load_model"

from keras.models import load_model
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# 89.63678208
# Mounted at /content/drive

# %%
import numpy as np
from tensorflow.keras import optimizers

# Download and import data preprocessing .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
from data_processing import data_bundle as data_bundle

# Download and import performance metrics .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
from performance_metrics import plot_ROC, plot_cm, plot_acc_loss
from sklearn.metrics import classification_report

# Download and import RN50 .py file
! wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/ResNet50.py
from ResNet50 import rn50_seei as rn50_class

# Download and import RN50 .py file
# Out:
# --2023-05-15 15:55:08--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3955 (3.9K) [text/plain]
# Saving to: ‘data_processing.py’
#
# data_processing.py  100%[===================>]   3.86K  --.-KB/s    in 0s
#
# 2023-05-15 15:55:08 (48.0 MB/s) - ‘data_processing.py’ saved [3955/3955]
#
# --2023-05-15 15:55:09--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3235 (3.2K) [text/plain]
# Saving to: ‘performance_metrics.py’
#
# performance_metrics 100%[===================>]   3.16K  --.-KB/s    in 0s
#
# 2023-05-15 15:55:10 (56.5 MB/s) - ‘performance_metrics.py’ saved [3235/3235]
#
# --2023-05-15 15:55:10--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/ResNet50.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3313 (3.2K) [text/plain]
# Saving to: ‘ResNet50.py’
#
# ResNet50.py         100%[===================>]   3.24K  --.-KB/s    in 0s
#
# 2023-05-15 15:55:10 (64.4 MB/s) - ‘ResNet50.py’ saved [3313/3313]

# %%
# Define relevant paths for appropriately instantiating the data_bundle class
images_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/images_224A_1000.npy"
popn_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/popn_224A_1000.npy"
target_var = "gdp"

# In this case GDP has been chose
if target_var == "gdp":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/gdp_224A_1000.npy"
  label_type = "GDPpercap"

elif target_var == "hdi":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/hdi_224A_1000.npy"
  label_type = "HDI"

# Instantiate data_bundle object
basic_bundle = data_bundle(images_path_0, popn_path_0, labels_path_0, label_type, augmented=True)

# Preprocess data through the data_bundle class' methods
basic_bundle.normalize_images()
basic_bundle.normalize_popn()
basic_bundle.bundle_inputs()
basic_bundle.split_data(0.4,0.5,2023)
basic_bundle.unbundle_and_shape_inputs()
basic_bundle.onehot_encode_labels()

# The resulting input sets are: self.X_tri, self.X_vai, self.X_tei (Images) and self.X_trp, self.X_vap, self.X_tep (Population)
# The resulting tragets are: self.y_train_onehot, self.y_val_onehot and self.y_test_onehot
# Where "self" is to be substituted by the given name to the data_bundle instance
# Out:
# /content/data_processing.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features = np.array(list(zip(self.images, np.array(self.popn))))

# %% [markdown]
# ### Model: ResNet50 - GDP per capita

# %%
# Eliminar learning rate de vgg.py y pasar el dropout a argumento de método y no de clase
rn_model = rn50_class(input_shape=(224, 224, 3))

rn_model.load_and_freeze_rn50()
rn_model.enable_dual_input()
rn_model.add_dense_layers(dropout_rate=0.25)
optimizer = sgd = optimizers.SGD(learning_rate=0.005)
rn_model.define_and_compile_model(optimizer=optimizer)
rn_model.fit_model(train_in=[basic_bundle.X_tri, basic_bundle.X_trp], train_tar=basic_bundle.y_train_onehot, 
                    validation_in=[basic_bundle.X_vai, basic_bundle.X_vap], validation_tar=basic_bundle.y_val_onehot, 
                    batch_size=80, epochs=100, es_patience=25)

# Note: if model is on single mode train_in and validation_in should have just one "input" instead of a list of two "inputs"

rn_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])

# model Save/Load  

example_save_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"
example_load_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"

#vgg_model.save(<path_here>)
#vgg_model.load(<path_here>)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 6s 0us/step
# Epoch 1/100
# 47/47 [==============================] - 19s 141ms/step - loss: 2.0308 - accuracy: 0.2852 - val_loss: 1.3855 - val_accuracy: 0.3070
# Epoch 2/100
# 47/47 [==============================] - 3s 62ms/step - loss: 1.3851 - accuracy: 0.3011 - val_loss: 1.3845 - val_accuracy: 0.3078
# Epoch 3/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3841 - accuracy: 0.3078 - val_loss: 1.3836 - val_accuracy: 0.3078
# Epoch 4/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3833 - accuracy: 0.3078 - val_loss: 1.3829 - val_accuracy: 0.3078
# Epoch 5/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3826 - accuracy: 0.3078 - val_loss: 1.3822 - val_accuracy: 0.3078
# Epoch 6/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3819 - accuracy: 0.3078 - val_loss: 1.3816 - val_accuracy: 0.3078
# Epoch 7/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3813 - accuracy: 0.3078 - val_loss: 1.3810 - val_accuracy: 0.3078
# Epoch 8/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3808 - accuracy: 0.3078 - val_loss: 1.3806 - val_accuracy: 0.3078
# Epoch 9/100
# 47/47 [==============================] - 3s 59ms/step - loss: 1.3804 - accuracy: 0.3078 - val_loss: 1.3801 - val_accuracy: 0.3078
# Epoch 10/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3800 - accuracy: 0.3078 - val_loss: 1.3798 - val_accuracy: 0.3078
# Epoch 11/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.3796 - accuracy: 0.3078 - val_loss: 1.3794 - val_accuracy: 0.3078
# Epoch 12/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3793 - accuracy: 0.3078 - val_loss: 1.3792 - val_accuracy: 0.3078
# Epoch 13/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3791 - accuracy: 0.3078 - val_loss: 1.3789 - val_accuracy: 0.3078
# Epoch 14/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.3788 - accuracy: 0.3078 - val_loss: 1.3787 - val_accuracy: 0.3078
# Epoch 15/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.3786 - accuracy: 0.3078 - val_loss: 1.3785 - val_accuracy: 0.3078
# Epoch 16/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3784 - accuracy: 0.3078 - val_loss: 1.3783 - val_accuracy: 0.3078
# Epoch 17/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.3782 - accuracy: 0.3078 - val_loss: 1.3781 - val_accuracy: 0.3078
# Epoch 18/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.3781 - accuracy: 0.3078 - val_loss: 1.3780 - val_accuracy: 0.3078
# Epoch 19/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3780 - accuracy: 0.3078 - val_loss: 1.3779 - val_accuracy: 0.3078
# Epoch 20/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.3779 - accuracy: 0.3078 - val_loss: 1.3778 - val_accuracy: 0.3078
# Epoch 21/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3778 - accuracy: 0.3078 - val_loss: 1.3777 - val_accuracy: 0.3078
# Epoch 22/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.3777 - accuracy: 0.3078 - val_loss: 1.3776 - val_accuracy: 0.3078
# Epoch 23/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3776 - accuracy: 0.3078 - val_loss: 1.3775 - val_accuracy: 0.3078
# Epoch 24/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3775 - accuracy: 0.3078 - val_loss: 1.3775 - val_accuracy: 0.3078
# Epoch 25/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3775 - accuracy: 0.3078 - val_loss: 1.3774 - val_accuracy: 0.3078
# Epoch 26/100
# 47/47 [==============================] - 3s 59ms/step - loss: 1.3774 - accuracy: 0.3078 - val_loss: 1.3773 - val_accuracy: 0.3078
# Epoch 27/100
# 47/47 [==============================] - 3s 62ms/step - loss: 1.3774 - accuracy: 0.3078 - val_loss: 1.3773 - val_accuracy: 0.3078
# 40/40 [==============================] - 2s 23ms/step

# %%
rn_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])
# Out:
# 40/40 [==============================] - 1s 18ms/step

# %%
# Val acc. and Val loss evolution
plot_acc_loss(rn_model.fit)

# %%
# ROC curves
plot_ROC(rn_model.predictions,basic_bundle.y_test_onehot,4)

# %%
# Confusion matrix
plot_cm(basic_bundle.y_test_onehot,rn_model.predictions)

# %%
# Clasification report
print(classification_report(np.argmax(basic_bundle.y_test_onehot, axis=1), np.argmax(rn_model.predictions, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       278
#            1       0.31      1.00      0.47       386
#            2       0.00      0.00      0.00       281
#            3       0.00      0.00      0.00       308
#
#     accuracy                           0.31      1253
#    macro avg       0.08      0.25      0.12      1253
# weighted avg       0.09      0.31      0.15      1253
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#rn_model.save("/content/drive/MyDrive/Thesis/M224A-1000/rn50_gdp_224A_1000_v1.h5")
