# %%
# Check RAM Memory

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
  
print(ram_gb)

# Login into drive

from google.colab import drive
drive.mount('/content/drive')

# Importing "load_model"

from keras.models import load_model
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# 89.63678208
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
from tensorflow.keras import optimizers

# Download and import data preprocessing .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
from data_processing import data_bundle as data_bundle

# Download and import performance metrics .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
from performance_metrics import plot_ROC, plot_cm, plot_acc_loss
from sklearn.metrics import classification_report

# Download and import VGG16 .py file
! wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/VGG16.py
from VGG16 import vgg16_seei as vgg16_class

# Download and import VGG16 .py file
# Out:
# --2023-05-15 15:41:30--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3955 (3.9K) [text/plain]
# Saving to: ‘data_processing.py.1’
#
# data_processing.py. 100%[===================>]   3.86K  --.-KB/s    in 0s
#
# 2023-05-15 15:41:30 (90.8 MB/s) - ‘data_processing.py.1’ saved [3955/3955]
#
# --2023-05-15 15:41:31--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3235 (3.2K) [text/plain]
# Saving to: ‘performance_metrics.py.1’
#
# performance_metrics 100%[===================>]   3.16K  --.-KB/s    in 0s
#
# 2023-05-15 15:41:31 (83.2 MB/s) - ‘performance_metrics.py.1’ saved [3235/3235]
#
# --2023-05-15 15:41:31--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/VGG16.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3565 (3.5K) [text/plain]
# Saving to: ‘VGG16.py.1’
#
# VGG16.py.1          100%[===================>]   3.48K  --.-KB/s    in 0s
#
# 2023-05-15 15:41:31 (54.1 MB/s) - ‘VGG16.py.1’ saved [3565/3565]

# %%
# Define relevant paths for appropriately instantiating the data_bundle class
images_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/images_224A_1000.npy"
popn_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/popn_224A_1000.npy"
target_var = "gdp"

# In this case GDP has been chose
if target_var == "gdp":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/gdp_224A_1000.npy"
  label_type = "GDPpercap"

elif target_var == "hdi":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/hdi_224A_1000.npy"
  label_type = "HDI"

# Instantiate data_bundle object
basic_bundle = data_bundle(images_path_0, popn_path_0, labels_path_0, label_type, augmented=True)

# Preprocess data through the data_bundle class' methods
basic_bundle.normalize_images()
basic_bundle.normalize_popn()
basic_bundle.bundle_inputs()
basic_bundle.split_data(0.4,0.5,2023)
basic_bundle.unbundle_and_shape_inputs()
basic_bundle.onehot_encode_labels()

# The resulting input sets are: self.X_tri, self.X_vai, self.X_tei (Images) and self.X_trp, self.X_vap, self.X_tep (Population)
# The resulting tragets are: self.y_train_onehot, self.y_val_onehot and self.y_test_onehot
# Where "self" is to be substituted by the given name to the data_bundle instance
# Out:
# /content/data_processing.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features = np.array(list(zip(self.images, np.array(self.popn))))

# %% [markdown]
# ### Model: VGG16 - GDP per capita

# %%
# Eliminar learning rate de vgg.py y pasar el dropout a argumento de método y no de clase
vgg_model = vgg16_class(input_shape=(224, 224, 3))

vgg_model.load_and_freeze_vgg16()
vgg_model.enable_dual_input()
vgg_model.add_dense_layers(dropout_rate=0.25)
optimizer = sgd = optimizers.SGD(learning_rate=0.005)
vgg_model.define_and_compile_model(optimizer=optimizer)
vgg_model.fit_model(train_in=[basic_bundle.X_tri, basic_bundle.X_trp], train_tar=basic_bundle.y_train_onehot, 
                    validation_in=[basic_bundle.X_vai, basic_bundle.X_vap], validation_tar=basic_bundle.y_val_onehot, 
                    batch_size=80, epochs=100, es_patience=25)

# Note: if model is on single mode train_in and validation_in should have just one "input" instead of a list of two "inputs"

vgg_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])

# model Save/Load  

example_save_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"
example_load_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"

#vgg_model.save(<path_here>)
#vgg_model.load(<path_here>)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 1s 0us/step
# Epoch 1/100
# 47/47 [==============================] - 20s 172ms/step - loss: 1.3902 - accuracy: 0.2953 - val_loss: 1.3625 - val_accuracy: 0.3668
# Epoch 2/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.3693 - accuracy: 0.3067 - val_loss: 1.3281 - val_accuracy: 0.3772
# Epoch 3/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.3531 - accuracy: 0.3155 - val_loss: 1.2991 - val_accuracy: 0.4139
# Epoch 4/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.3407 - accuracy: 0.3312 - val_loss: 1.2811 - val_accuracy: 0.4266
# Epoch 5/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.3191 - accuracy: 0.3496 - val_loss: 1.2622 - val_accuracy: 0.4386
# Epoch 6/100
# 47/47 [==============================] - 3s 73ms/step - loss: 1.2933 - accuracy: 0.3746 - val_loss: 1.2166 - val_accuracy: 0.4386
# Epoch 7/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.2767 - accuracy: 0.3738 - val_loss: 1.2497 - val_accuracy: 0.4147
# Epoch 8/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.2522 - accuracy: 0.3900 - val_loss: 1.2005 - val_accuracy: 0.4394
# Epoch 9/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.2438 - accuracy: 0.3924 - val_loss: 1.1848 - val_accuracy: 0.4330
# Epoch 10/100
# 47/47 [==============================] - 4s 76ms/step - loss: 1.2367 - accuracy: 0.3972 - val_loss: 1.1579 - val_accuracy: 0.4545
# Epoch 11/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.2241 - accuracy: 0.4068 - val_loss: 1.1546 - val_accuracy: 0.4561
# Epoch 12/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.2029 - accuracy: 0.4283 - val_loss: 1.1437 - val_accuracy: 0.4673
# Epoch 13/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1989 - accuracy: 0.4129 - val_loss: 1.1118 - val_accuracy: 0.4617
# Epoch 14/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1861 - accuracy: 0.4217 - val_loss: 1.1250 - val_accuracy: 0.4617
# Epoch 15/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1748 - accuracy: 0.4360 - val_loss: 1.1028 - val_accuracy: 0.4633
# Epoch 16/100
# 47/47 [==============================] - 3s 73ms/step - loss: 1.1762 - accuracy: 0.4299 - val_loss: 1.1036 - val_accuracy: 0.4490
# Epoch 17/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1743 - accuracy: 0.4358 - val_loss: 1.1405 - val_accuracy: 0.4537
# Epoch 18/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1565 - accuracy: 0.4405 - val_loss: 1.0968 - val_accuracy: 0.4601
# Epoch 19/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.1645 - accuracy: 0.4371 - val_loss: 1.0996 - val_accuracy: 0.4713
# Epoch 20/100
# 47/47 [==============================] - 3s 73ms/step - loss: 1.1451 - accuracy: 0.4363 - val_loss: 1.1005 - val_accuracy: 0.4545
# Epoch 21/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.1383 - accuracy: 0.4448 - val_loss: 1.0932 - val_accuracy: 0.4777
# Epoch 22/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.1353 - accuracy: 0.4384 - val_loss: 1.0928 - val_accuracy: 0.4785
# Epoch 23/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1287 - accuracy: 0.4530 - val_loss: 1.1183 - val_accuracy: 0.4537
# Epoch 24/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1306 - accuracy: 0.4408 - val_loss: 1.0733 - val_accuracy: 0.4737
# Epoch 25/100
# 47/47 [==============================] - 3s 73ms/step - loss: 1.1249 - accuracy: 0.4509 - val_loss: 1.1718 - val_accuracy: 0.4370
# Epoch 26/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.1218 - accuracy: 0.4477 - val_loss: 1.0785 - val_accuracy: 0.4896
# Epoch 27/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1116 - accuracy: 0.4634 - val_loss: 1.0783 - val_accuracy: 0.4785
# Epoch 28/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1125 - accuracy: 0.4530 - val_loss: 1.0655 - val_accuracy: 0.4841
# Epoch 29/100
# 47/47 [==============================] - 3s 73ms/step - loss: 1.1169 - accuracy: 0.4475 - val_loss: 1.1120 - val_accuracy: 0.4657
# Epoch 30/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0921 - accuracy: 0.4645 - val_loss: 1.0455 - val_accuracy: 0.5016
# Epoch 31/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0921 - accuracy: 0.4759 - val_loss: 1.0679 - val_accuracy: 0.5008
# Epoch 32/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0959 - accuracy: 0.4733 - val_loss: 1.0466 - val_accuracy: 0.5064
# Epoch 33/100
# 47/47 [==============================] - 3s 73ms/step - loss: 1.0881 - accuracy: 0.4687 - val_loss: 1.0474 - val_accuracy: 0.5040
# Epoch 34/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0991 - accuracy: 0.4727 - val_loss: 1.1431 - val_accuracy: 0.4346
# Epoch 35/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0978 - accuracy: 0.4682 - val_loss: 1.0311 - val_accuracy: 0.5064
# Epoch 36/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0737 - accuracy: 0.4757 - val_loss: 1.1449 - val_accuracy: 0.4506
# Epoch 37/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0855 - accuracy: 0.4621 - val_loss: 1.0986 - val_accuracy: 0.4761
# Epoch 38/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0803 - accuracy: 0.4727 - val_loss: 1.0335 - val_accuracy: 0.5287
# Epoch 39/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0640 - accuracy: 0.4818 - val_loss: 1.0244 - val_accuracy: 0.5199
# Epoch 40/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0621 - accuracy: 0.4943 - val_loss: 1.0613 - val_accuracy: 0.5144
# Epoch 41/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0751 - accuracy: 0.4775 - val_loss: 1.1515 - val_accuracy: 0.4250
# Epoch 42/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0568 - accuracy: 0.4911 - val_loss: 1.0487 - val_accuracy: 0.5048
# Epoch 43/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0668 - accuracy: 0.4879 - val_loss: 1.0333 - val_accuracy: 0.5175
# Epoch 44/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0542 - accuracy: 0.4892 - val_loss: 1.0176 - val_accuracy: 0.5199
# Epoch 45/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0483 - accuracy: 0.4855 - val_loss: 1.0192 - val_accuracy: 0.5239
# Epoch 46/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0479 - accuracy: 0.4906 - val_loss: 1.0203 - val_accuracy: 0.5159
# Epoch 47/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0264 - accuracy: 0.5137 - val_loss: 1.0410 - val_accuracy: 0.5120
# Epoch 48/100
# 47/47 [==============================] - 4s 76ms/step - loss: 1.0433 - accuracy: 0.4932 - val_loss: 1.0036 - val_accuracy: 0.5399
# Epoch 49/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0390 - accuracy: 0.5031 - val_loss: 1.0452 - val_accuracy: 0.4936
# Epoch 50/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0390 - accuracy: 0.5049 - val_loss: 0.9961 - val_accuracy: 0.5359
# Epoch 51/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0362 - accuracy: 0.4964 - val_loss: 1.0246 - val_accuracy: 0.5383
# Epoch 52/100
# 47/47 [==============================] - 3s 73ms/step - loss: 1.0133 - accuracy: 0.5113 - val_loss: 1.1633 - val_accuracy: 0.4585
# Epoch 53/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0630 - accuracy: 0.4871 - val_loss: 1.0244 - val_accuracy: 0.5391
# Epoch 54/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0373 - accuracy: 0.5033 - val_loss: 1.0220 - val_accuracy: 0.5367
# Epoch 55/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0207 - accuracy: 0.5052 - val_loss: 0.9803 - val_accuracy: 0.5455
# Epoch 56/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0303 - accuracy: 0.5020 - val_loss: 0.9914 - val_accuracy: 0.5375
# Epoch 57/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0113 - accuracy: 0.5129 - val_loss: 0.9824 - val_accuracy: 0.5526
# Epoch 58/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0093 - accuracy: 0.5206 - val_loss: 1.0965 - val_accuracy: 0.4872
# Epoch 59/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0146 - accuracy: 0.5243 - val_loss: 1.0206 - val_accuracy: 0.5327
# Epoch 60/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9937 - accuracy: 0.5251 - val_loss: 0.9773 - val_accuracy: 0.5407
# Epoch 61/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0224 - accuracy: 0.5177 - val_loss: 0.9784 - val_accuracy: 0.5486
# Epoch 62/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9976 - accuracy: 0.5331 - val_loss: 0.9684 - val_accuracy: 0.5566
# Epoch 63/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0148 - accuracy: 0.5089 - val_loss: 0.9987 - val_accuracy: 0.5622
# Epoch 64/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0083 - accuracy: 0.5241 - val_loss: 1.0198 - val_accuracy: 0.5327
# Epoch 65/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0105 - accuracy: 0.5352 - val_loss: 0.9668 - val_accuracy: 0.5502
# Epoch 66/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0007 - accuracy: 0.5326 - val_loss: 1.2571 - val_accuracy: 0.4450
# Epoch 67/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0358 - accuracy: 0.5060 - val_loss: 1.1492 - val_accuracy: 0.4625
# Epoch 68/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0184 - accuracy: 0.5235 - val_loss: 1.0322 - val_accuracy: 0.5128
# Epoch 69/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0017 - accuracy: 0.5177 - val_loss: 0.9669 - val_accuracy: 0.5646
# Epoch 70/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0089 - accuracy: 0.5235 - val_loss: 1.0550 - val_accuracy: 0.4809
# Epoch 71/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9947 - accuracy: 0.5339 - val_loss: 1.0081 - val_accuracy: 0.5447
# Epoch 72/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0129 - accuracy: 0.5153 - val_loss: 0.9767 - val_accuracy: 0.5502
# Epoch 73/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0145 - accuracy: 0.5180 - val_loss: 0.9621 - val_accuracy: 0.5710
# Epoch 74/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9861 - accuracy: 0.5390 - val_loss: 1.0235 - val_accuracy: 0.5343
# Epoch 75/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0133 - accuracy: 0.5108 - val_loss: 0.9808 - val_accuracy: 0.5582
# Epoch 76/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9709 - accuracy: 0.5414 - val_loss: 0.9572 - val_accuracy: 0.5654
# Epoch 77/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9846 - accuracy: 0.5294 - val_loss: 0.9698 - val_accuracy: 0.5550
# Epoch 78/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9876 - accuracy: 0.5329 - val_loss: 1.0212 - val_accuracy: 0.5391
# Epoch 79/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9941 - accuracy: 0.5355 - val_loss: 1.0827 - val_accuracy: 0.5032
# Epoch 80/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9981 - accuracy: 0.5153 - val_loss: 0.9616 - val_accuracy: 0.5614
# Epoch 81/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9635 - accuracy: 0.5557 - val_loss: 0.9493 - val_accuracy: 0.5710
# Epoch 82/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9652 - accuracy: 0.5557 - val_loss: 1.1951 - val_accuracy: 0.4657
# Epoch 83/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.9617 - accuracy: 0.5523 - val_loss: 0.9436 - val_accuracy: 0.5781
# Epoch 84/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9726 - accuracy: 0.5480 - val_loss: 0.9545 - val_accuracy: 0.5574
# Epoch 85/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9624 - accuracy: 0.5451 - val_loss: 0.9324 - val_accuracy: 0.5853
# Epoch 86/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9639 - accuracy: 0.5517 - val_loss: 0.9357 - val_accuracy: 0.5598
# Epoch 87/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.9424 - accuracy: 0.5629 - val_loss: 0.9577 - val_accuracy: 0.5526
# Epoch 88/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9341 - accuracy: 0.5642 - val_loss: 0.9787 - val_accuracy: 0.5375
# Epoch 89/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9655 - accuracy: 0.5541 - val_loss: 0.9877 - val_accuracy: 0.5486
# Epoch 90/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9737 - accuracy: 0.5355 - val_loss: 1.0110 - val_accuracy: 0.5343
# Epoch 91/100
# 47/47 [==============================] - 3s 73ms/step - loss: 0.9557 - accuracy: 0.5544 - val_loss: 0.9643 - val_accuracy: 0.5518
# Epoch 92/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9404 - accuracy: 0.5619 - val_loss: 0.9605 - val_accuracy: 0.5726
# Epoch 93/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9559 - accuracy: 0.5509 - val_loss: 0.9804 - val_accuracy: 0.5375
# Epoch 94/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9362 - accuracy: 0.5680 - val_loss: 0.9317 - val_accuracy: 0.5742
# Epoch 95/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9649 - accuracy: 0.5408 - val_loss: 0.9958 - val_accuracy: 0.5279
# Epoch 96/100
# 47/47 [==============================] - 3s 73ms/step - loss: 0.9508 - accuracy: 0.5547 - val_loss: 0.9467 - val_accuracy: 0.5734
# Epoch 97/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9732 - accuracy: 0.5427 - val_loss: 0.9481 - val_accuracy: 0.5662
# Epoch 98/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9222 - accuracy: 0.5770 - val_loss: 0.9784 - val_accuracy: 0.5518
# Epoch 99/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9430 - accuracy: 0.5563 - val_loss: 0.9745 - val_accuracy: 0.5582
# Epoch 100/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9240 - accuracy: 0.5791 - val_loss: 0.9483 - val_accuracy: 0.5813
# 40/40 [==============================] - 2s 28ms/step

# %%
vgg_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])
# Out:
# 40/40 [==============================] - 1s 21ms/step

# %%
# Val acc. and Val loss evolution
plot_acc_loss(vgg_model.fit)

# %%
# ROC curves
plot_ROC(vgg_model.predictions,basic_bundle.y_test_onehot,4)

# %%
# Confusion matrix
plot_cm(basic_bundle.y_test_onehot,vgg_model.predictions)

# %%
# Clasification report
print(classification_report(np.argmax(basic_bundle.y_test_onehot, axis=1), np.argmax(vgg_model.predictions, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.63       278
#            1       0.46      0.62      0.53       386
#            2       0.46      0.37      0.41       281
#            3       0.75      0.55      0.64       308
#
#     accuracy                           0.55      1253
#    macro avg       0.57      0.55      0.55      1253
# weighted avg       0.57      0.55      0.55      1253

# %%
#vgg_model.save("/content/drive/MyDrive/Thesis/M224A-1000/vgg16_gdp_224A_1000_v1.h5")
