# %%
# Check RAM Memory

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
  
print(ram_gb)

# Login into drive

from google.colab import drive
drive.mount('/content/drive')

# Importing "load_model"

from keras.models import load_model
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# 89.63678208
# Mounted at /content/drive

# %%
import numpy as np
from tensorflow.keras import optimizers

# Download and import data preprocessing .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
from data_processing import data_bundle as data_bundle

# Download and import performance metrics .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
from performance_metrics import plot_ROC, plot_cm, plot_acc_loss
from sklearn.metrics import classification_report

# Download and import RN50 .py file
! wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/ResNet50.py
from ResNet50 import rn50_seei as rn50_class

# Download and import RN50 .py file
# Out:
# --2023-05-15 15:43:03--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3955 (3.9K) [text/plain]
# Saving to: ‘data_processing.py’
#
# data_processing.py  100%[===================>]   3.86K  --.-KB/s    in 0s
#
# 2023-05-15 15:43:03 (47.3 MB/s) - ‘data_processing.py’ saved [3955/3955]
#
# --2023-05-15 15:43:04--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3235 (3.2K) [text/plain]
# Saving to: ‘performance_metrics.py’
#
# performance_metrics 100%[===================>]   3.16K  --.-KB/s    in 0s
#
# 2023-05-15 15:43:04 (62.4 MB/s) - ‘performance_metrics.py’ saved [3235/3235]
#
# --2023-05-15 15:43:04--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/ResNet50.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3313 (3.2K) [text/plain]
# Saving to: ‘ResNet50.py’
#
# ResNet50.py         100%[===================>]   3.24K  --.-KB/s    in 0s
#
# 2023-05-15 15:43:04 (45.4 MB/s) - ‘ResNet50.py’ saved [3313/3313]

# %%
# Define relevant paths for appropriately instantiating the data_bundle class
images_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/images_224A_1000.npy"
popn_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/popn_224A_1000.npy"
target_var = "hdi"

# In this case GDP has been chose
if target_var == "gdp":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/gdp_224A_1000.npy"
  label_type = "GDPpercap"

elif target_var == "hdi":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/hdi_224A_1000.npy"
  label_type = "HDI"

# Instantiate data_bundle object
basic_bundle = data_bundle(images_path_0, popn_path_0, labels_path_0, label_type, augmented=True)

# Preprocess data through the data_bundle class' methods
basic_bundle.normalize_images()
basic_bundle.normalize_popn()
basic_bundle.bundle_inputs()
basic_bundle.split_data(0.4,0.5,2023)
basic_bundle.unbundle_and_shape_inputs()
basic_bundle.onehot_encode_labels()

# The resulting input sets are: self.X_tri, self.X_vai, self.X_tei (Images) and self.X_trp, self.X_vap, self.X_tep (Population)
# The resulting tragets are: self.y_train_onehot, self.y_val_onehot and self.y_test_onehot
# Where "self" is to be substituted by the given name to the data_bundle instance
# Out:
# /content/data_processing.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features = np.array(list(zip(self.images, np.array(self.popn))))

# %% [markdown]
# ### Model: ResNet50 - HDI

# %%
# Eliminar learning rate de vgg.py y pasar el dropout a argumento de método y no de clase
rn_model = rn50_class(input_shape=(224, 224, 3))

rn_model.load_and_freeze_rn50()
rn_model.enable_dual_input()
rn_model.add_dense_layers(dropout_rate=0.25)
optimizer = sgd = optimizers.SGD(learning_rate=0.005)
rn_model.define_and_compile_model(optimizer=optimizer)
rn_model.fit_model(train_in=[basic_bundle.X_tri, basic_bundle.X_trp], train_tar=basic_bundle.y_train_onehot, 
                    validation_in=[basic_bundle.X_vai, basic_bundle.X_vap], validation_tar=basic_bundle.y_val_onehot, 
                    batch_size=80, epochs=100, es_patience=25)

# Note: if model is on single mode train_in and validation_in should have just one "input" instead of a list of two "inputs"

rn_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])

# model Save/Load  

example_save_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"
example_load_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"

#vgg_model.save(<path_here>)
#vgg_model.load(<path_here>)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 7s 0us/step
# Epoch 1/100
# 47/47 [==============================] - 19s 140ms/step - loss: 1.6284 - accuracy: 0.2535 - val_loss: 1.3835 - val_accuracy: 0.2600
# Epoch 2/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.3837 - accuracy: 0.2727 - val_loss: 1.3952 - val_accuracy: 0.2520
# Epoch 3/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3807 - accuracy: 0.2780 - val_loss: 1.3826 - val_accuracy: 0.2520
# Epoch 4/100
# 47/47 [==============================] - 3s 61ms/step - loss: 1.3720 - accuracy: 0.3099 - val_loss: 1.3748 - val_accuracy: 0.2735
# Epoch 5/100
# 47/47 [==============================] - 3s 62ms/step - loss: 1.3559 - accuracy: 0.3352 - val_loss: 1.3431 - val_accuracy: 0.4362
# Epoch 6/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3415 - accuracy: 0.3509 - val_loss: 1.3213 - val_accuracy: 0.4171
# Epoch 7/100
# 47/47 [==============================] - 3s 62ms/step - loss: 1.3381 - accuracy: 0.3480 - val_loss: 1.3108 - val_accuracy: 0.4593
# Epoch 8/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.3135 - accuracy: 0.3631 - val_loss: 1.2690 - val_accuracy: 0.4139
# Epoch 9/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.3272 - accuracy: 0.3493 - val_loss: 1.3603 - val_accuracy: 0.2935
# Epoch 10/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.2913 - accuracy: 0.3618 - val_loss: 1.2310 - val_accuracy: 0.4378
# Epoch 11/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.3089 - accuracy: 0.3674 - val_loss: 1.2315 - val_accuracy: 0.4083
# Epoch 12/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.2736 - accuracy: 0.3770 - val_loss: 1.4513 - val_accuracy: 0.2663
# Epoch 13/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.2719 - accuracy: 0.3796 - val_loss: 1.2566 - val_accuracy: 0.4458
# Epoch 14/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.2695 - accuracy: 0.3913 - val_loss: 1.2281 - val_accuracy: 0.3979
# Epoch 15/100
# 47/47 [==============================] - 3s 61ms/step - loss: 1.2441 - accuracy: 0.3969 - val_loss: 1.1618 - val_accuracy: 0.4697
# Epoch 16/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.2506 - accuracy: 0.3889 - val_loss: 1.2110 - val_accuracy: 0.4657
# Epoch 17/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.2322 - accuracy: 0.3964 - val_loss: 1.1564 - val_accuracy: 0.4601
# Epoch 18/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.2065 - accuracy: 0.4243 - val_loss: 1.1990 - val_accuracy: 0.4649
# Epoch 19/100
# 47/47 [==============================] - 3s 61ms/step - loss: 1.2077 - accuracy: 0.4129 - val_loss: 1.1855 - val_accuracy: 0.4809
# Epoch 20/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1880 - accuracy: 0.4328 - val_loss: 1.2420 - val_accuracy: 0.4075
# Epoch 21/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.2076 - accuracy: 0.4251 - val_loss: 1.2005 - val_accuracy: 0.4569
# Epoch 22/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.2043 - accuracy: 0.4251 - val_loss: 1.3342 - val_accuracy: 0.3038
# Epoch 23/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1919 - accuracy: 0.4278 - val_loss: 1.1765 - val_accuracy: 0.4354
# Epoch 24/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1774 - accuracy: 0.4387 - val_loss: 1.1361 - val_accuracy: 0.4530
# Epoch 25/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1506 - accuracy: 0.4514 - val_loss: 1.1776 - val_accuracy: 0.4147
# Epoch 26/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1751 - accuracy: 0.4328 - val_loss: 1.1522 - val_accuracy: 0.4745
# Epoch 27/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1813 - accuracy: 0.4453 - val_loss: 1.1319 - val_accuracy: 0.4761
# Epoch 28/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1605 - accuracy: 0.4663 - val_loss: 1.1437 - val_accuracy: 0.4585
# Epoch 29/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1480 - accuracy: 0.4528 - val_loss: 1.2649 - val_accuracy: 0.3939
# Epoch 30/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1588 - accuracy: 0.4536 - val_loss: 1.1314 - val_accuracy: 0.4801
# Epoch 31/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1584 - accuracy: 0.4576 - val_loss: 1.2874 - val_accuracy: 0.3900
# Epoch 32/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1625 - accuracy: 0.4453 - val_loss: 1.1746 - val_accuracy: 0.4386
# Epoch 33/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1352 - accuracy: 0.4645 - val_loss: 1.1294 - val_accuracy: 0.4585
# Epoch 34/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1449 - accuracy: 0.4645 - val_loss: 1.1067 - val_accuracy: 0.4753
# Epoch 35/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1509 - accuracy: 0.4616 - val_loss: 1.1412 - val_accuracy: 0.4745
# Epoch 36/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1401 - accuracy: 0.4658 - val_loss: 1.1413 - val_accuracy: 0.4577
# Epoch 37/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1302 - accuracy: 0.4650 - val_loss: 1.1285 - val_accuracy: 0.4801
# Epoch 38/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1416 - accuracy: 0.4589 - val_loss: 1.1902 - val_accuracy: 0.4386
# Epoch 39/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1459 - accuracy: 0.4584 - val_loss: 1.1211 - val_accuracy: 0.4649
# Epoch 40/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1107 - accuracy: 0.4773 - val_loss: 1.1003 - val_accuracy: 0.4793
# Epoch 41/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1419 - accuracy: 0.4549 - val_loss: 1.1880 - val_accuracy: 0.4370
# Epoch 42/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1359 - accuracy: 0.4632 - val_loss: 1.1869 - val_accuracy: 0.4498
# Epoch 43/100
# 47/47 [==============================] - 3s 61ms/step - loss: 1.1451 - accuracy: 0.4581 - val_loss: 1.1011 - val_accuracy: 0.4833
# Epoch 44/100
# 47/47 [==============================] - 3s 62ms/step - loss: 1.1309 - accuracy: 0.4578 - val_loss: 1.0966 - val_accuracy: 0.4912
# Epoch 45/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1257 - accuracy: 0.4600 - val_loss: 1.1014 - val_accuracy: 0.4856
# Epoch 46/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1008 - accuracy: 0.4839 - val_loss: 1.0929 - val_accuracy: 0.4801
# Epoch 47/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1117 - accuracy: 0.4823 - val_loss: 1.1046 - val_accuracy: 0.4872
# Epoch 48/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1160 - accuracy: 0.4746 - val_loss: 1.1073 - val_accuracy: 0.4864
# Epoch 49/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.0999 - accuracy: 0.4818 - val_loss: 1.1658 - val_accuracy: 0.4649
# Epoch 50/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1157 - accuracy: 0.4786 - val_loss: 1.2016 - val_accuracy: 0.4386
# Epoch 51/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1260 - accuracy: 0.4573 - val_loss: 1.1880 - val_accuracy: 0.4370
# Epoch 52/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.0968 - accuracy: 0.4871 - val_loss: 1.0989 - val_accuracy: 0.4809
# Epoch 53/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1211 - accuracy: 0.4711 - val_loss: 1.0909 - val_accuracy: 0.4761
# Epoch 54/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1213 - accuracy: 0.4749 - val_loss: 1.1166 - val_accuracy: 0.4801
# Epoch 55/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1340 - accuracy: 0.4621 - val_loss: 1.2710 - val_accuracy: 0.3780
# Epoch 56/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1112 - accuracy: 0.4823 - val_loss: 1.1138 - val_accuracy: 0.4817
# Epoch 57/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1182 - accuracy: 0.4786 - val_loss: 1.1335 - val_accuracy: 0.4737
# Epoch 58/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1083 - accuracy: 0.4804 - val_loss: 1.1777 - val_accuracy: 0.4442
# Epoch 59/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1086 - accuracy: 0.4759 - val_loss: 1.0900 - val_accuracy: 0.4833
# Epoch 60/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1088 - accuracy: 0.4807 - val_loss: 1.1557 - val_accuracy: 0.4506
# Epoch 61/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1148 - accuracy: 0.4754 - val_loss: 1.0885 - val_accuracy: 0.4753
# Epoch 62/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1007 - accuracy: 0.4860 - val_loss: 1.1644 - val_accuracy: 0.4506
# Epoch 63/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1154 - accuracy: 0.4730 - val_loss: 1.2179 - val_accuracy: 0.4107
# Epoch 64/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1153 - accuracy: 0.4775 - val_loss: 1.1042 - val_accuracy: 0.4785
# Epoch 65/100
# 47/47 [==============================] - 3s 61ms/step - loss: 1.1058 - accuracy: 0.4767 - val_loss: 1.0925 - val_accuracy: 0.4944
# Epoch 66/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1030 - accuracy: 0.4765 - val_loss: 1.0877 - val_accuracy: 0.4833
# Epoch 67/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1072 - accuracy: 0.4828 - val_loss: 1.0878 - val_accuracy: 0.4896
# Epoch 68/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1081 - accuracy: 0.4786 - val_loss: 1.2245 - val_accuracy: 0.4123
# Epoch 69/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1062 - accuracy: 0.4815 - val_loss: 1.1137 - val_accuracy: 0.4912
# Epoch 70/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1031 - accuracy: 0.4794 - val_loss: 1.0818 - val_accuracy: 0.4817
# Epoch 71/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1136 - accuracy: 0.4855 - val_loss: 1.1727 - val_accuracy: 0.4282
# Epoch 72/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.0981 - accuracy: 0.4818 - val_loss: 1.0839 - val_accuracy: 0.4848
# Epoch 73/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1098 - accuracy: 0.4727 - val_loss: 1.0871 - val_accuracy: 0.4833
# Epoch 74/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1059 - accuracy: 0.4778 - val_loss: 1.1287 - val_accuracy: 0.4793
# Epoch 75/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.0911 - accuracy: 0.4842 - val_loss: 1.1009 - val_accuracy: 0.4928
# Epoch 76/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1127 - accuracy: 0.4807 - val_loss: 1.0808 - val_accuracy: 0.4848
# Epoch 77/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.0959 - accuracy: 0.4826 - val_loss: 1.1001 - val_accuracy: 0.4825
# Epoch 78/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1024 - accuracy: 0.4818 - val_loss: 1.0831 - val_accuracy: 0.4848
# Epoch 79/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1023 - accuracy: 0.4730 - val_loss: 1.1899 - val_accuracy: 0.4569
# Epoch 80/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1042 - accuracy: 0.4823 - val_loss: 1.1548 - val_accuracy: 0.4561
# Epoch 81/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.0947 - accuracy: 0.4895 - val_loss: 1.0946 - val_accuracy: 0.4904
# Epoch 82/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.0995 - accuracy: 0.4834 - val_loss: 1.1215 - val_accuracy: 0.4721
# Epoch 83/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.0894 - accuracy: 0.4882 - val_loss: 1.0820 - val_accuracy: 0.4864
# Epoch 84/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.0956 - accuracy: 0.4820 - val_loss: 1.0933 - val_accuracy: 0.4872
# Epoch 85/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1011 - accuracy: 0.4807 - val_loss: 1.0799 - val_accuracy: 0.4888
# Epoch 86/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.1098 - accuracy: 0.4802 - val_loss: 1.0865 - val_accuracy: 0.4928
# Epoch 87/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.1036 - accuracy: 0.4762 - val_loss: 1.1201 - val_accuracy: 0.4841
# Epoch 88/100
# 47/47 [==============================] - 3s 58ms/step - loss: 1.0833 - accuracy: 0.4839 - val_loss: 1.0858 - val_accuracy: 0.4904
# Epoch 89/100
# 47/47 [==============================] - 3s 57ms/step - loss: 1.0986 - accuracy: 0.4943 - val_loss: 1.1026 - val_accuracy: 0.4825
# Epoch 90/100
# 47/47 [==============================] - 3s 62ms/step - loss: 1.0999 - accuracy: 0.4839 - val_loss: 1.1031 - val_accuracy: 0.4777
# 40/40 [==============================] - 2s 22ms/step

# %%
rn_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])
# Out:
# 40/40 [==============================] - 1s 17ms/step

# %%
# Val acc. and Val loss evolution
plot_acc_loss(rn_model.fit)

# %%
# ROC curves
plot_ROC(rn_model.predictions,basic_bundle.y_test_onehot,4)

# %%
# Confusion matrix
plot_cm(basic_bundle.y_test_onehot,rn_model.predictions)

# %%
# Clasification report
print(classification_report(np.argmax(basic_bundle.y_test_onehot, axis=1), np.argmax(rn_model.predictions, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.64      0.68       342
#            1       0.35      0.33      0.34       270
#            2       0.38      0.20      0.26       316
#            3       0.48      0.79      0.60       325
#
#     accuracy                           0.50      1253
#    macro avg       0.49      0.49      0.47      1253
# weighted avg       0.50      0.50      0.48      1253

# %%
#rn_model.save("/content/drive/MyDrive/Thesis/M224A-1000/rn50_hdi_224A_1000_v1.h5")
