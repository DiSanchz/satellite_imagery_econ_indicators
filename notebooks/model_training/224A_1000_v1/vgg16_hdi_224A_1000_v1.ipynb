# %%
# Check RAM Memory

from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
  
print(ram_gb)

# Login into drive

from google.colab import drive
drive.mount('/content/drive')

# Importing "load_model"

from keras.models import load_model
# Out:
# Your runtime has 89.6 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# 89.63678208
# Mounted at /content/drive

# %%
import numpy as np
from tensorflow.keras import optimizers

# Download and import data preprocessing .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
from data_processing import data_bundle as data_bundle

# Download and import performance metrics .py file
# !wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
from performance_metrics import plot_ROC, plot_cm, plot_acc_loss
from sklearn.metrics import classification_report

# Download and import VGG16 .py file
! wget https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/VGG16.py
from VGG16 import vgg16_seei as vgg16_class

# Download and import VGG16 .py file
# Out:
# --2023-05-15 15:24:01--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/data_processing.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3955 (3.9K) [text/plain]
# Saving to: ‘data_processing.py’
#
# data_processing.py  100%[===================>]   3.86K  --.-KB/s    in 0s
#
# 2023-05-15 15:24:01 (68.0 MB/s) - ‘data_processing.py’ saved [3955/3955]
#
# --2023-05-15 15:24:02--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/performance_metrics.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3235 (3.2K) [text/plain]
# Saving to: ‘performance_metrics.py’
#
# performance_metrics 100%[===================>]   3.16K  --.-KB/s    in 0s
#
# 2023-05-15 15:24:02 (65.4 MB/s) - ‘performance_metrics.py’ saved [3235/3235]
#
# --2023-05-15 15:24:02--  https://raw.githubusercontent.com/DiSanchz/satellite_imagery_econ_indicators/main/satellite_imagery_econ_indicators/VGG16.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3565 (3.5K) [text/plain]
# Saving to: ‘VGG16.py’
#
# VGG16.py            100%[===================>]   3.48K  --.-KB/s    in 0s
#
# 2023-05-15 15:24:03 (69.8 MB/s) - ‘VGG16.py’ saved [3565/3565]

# %%
# Define relevant paths for appropriately instantiating the data_bundle class
images_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/images_224A_1000.npy"
popn_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/popn_224A_1000.npy"
target_var = "hdi"

# In this case GDP has been chose
if target_var == "gdp":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/gdp_224A_1000.npy"
  label_type = "GDPpercap"

elif target_var == "hdi":
  labels_path_0 = "/content/drive/MyDrive/Thesis/M224A-1000/inputs/hdi_224A_1000.npy"
  label_type = "HDI"

# Instantiate data_bundle object
basic_bundle = data_bundle(images_path_0, popn_path_0, labels_path_0, label_type, augmented=True)

# Preprocess data through the data_bundle class' methods
basic_bundle.normalize_images()
basic_bundle.normalize_popn()
basic_bundle.bundle_inputs()
basic_bundle.split_data(0.4,0.5,2023)
basic_bundle.unbundle_and_shape_inputs()
basic_bundle.onehot_encode_labels()

# The resulting input sets are: self.X_tri, self.X_vai, self.X_tei (Images) and self.X_trp, self.X_vap, self.X_tep (Population)
# The resulting tragets are: self.y_train_onehot, self.y_val_onehot and self.y_test_onehot
# Where "self" is to be substituted by the given name to the data_bundle instance
# Out:
# /content/data_processing.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   features = np.array(list(zip(self.images, np.array(self.popn))))

# %% [markdown]
# ### Model: VGG16 - HDI

# %%
# Eliminar learning rate de vgg.py y pasar el dropout a argumento de método y no de clase
vgg_model = vgg16_class(input_shape=(224, 224, 3))

vgg_model.load_and_freeze_vgg16()
vgg_model.enable_dual_input()
vgg_model.add_dense_layers(dropout_rate=0.25)
optimizer = sgd = optimizers.SGD(learning_rate=0.005)
vgg_model.define_and_compile_model(optimizer=optimizer)
vgg_model.fit_model(train_in=[basic_bundle.X_tri, basic_bundle.X_trp], train_tar=basic_bundle.y_train_onehot, 
                    validation_in=[basic_bundle.X_vai, basic_bundle.X_vap], validation_tar=basic_bundle.y_val_onehot, 
                    batch_size=80, epochs=100, es_patience=25)

# Note: if model is on single mode train_in and validation_in should have just one "input" instead of a list of two "inputs"

vgg_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])

# model Save/Load  

example_save_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"
example_load_path = "/content/drive/MyDrive/Thesis/vgg16_v0.h5"

#vgg_model.save(<path_here>)
#vgg_model.load(<path_here>)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 19s 172ms/step - loss: 1.4008 - accuracy: 0.2567 - val_loss: 1.3701 - val_accuracy: 0.4083
# Epoch 2/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.3770 - accuracy: 0.2650 - val_loss: 1.3538 - val_accuracy: 0.3333
# Epoch 3/100
# 47/47 [==============================] - 4s 76ms/step - loss: 1.3638 - accuracy: 0.2852 - val_loss: 1.3412 - val_accuracy: 0.4115
# Epoch 4/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.3463 - accuracy: 0.3075 - val_loss: 1.3263 - val_accuracy: 0.4569
# Epoch 5/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.3311 - accuracy: 0.3320 - val_loss: 1.3009 - val_accuracy: 0.4099
# Epoch 6/100
# 47/47 [==============================] - 4s 76ms/step - loss: 1.3122 - accuracy: 0.3748 - val_loss: 1.2809 - val_accuracy: 0.4027
# Epoch 7/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.2964 - accuracy: 0.3951 - val_loss: 1.2623 - val_accuracy: 0.5167
# Epoch 8/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.2814 - accuracy: 0.4280 - val_loss: 1.2409 - val_accuracy: 0.5136
# Epoch 9/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.2704 - accuracy: 0.4280 - val_loss: 1.2480 - val_accuracy: 0.5032
# Epoch 10/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.2574 - accuracy: 0.4512 - val_loss: 1.2606 - val_accuracy: 0.4665
# Epoch 11/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.2512 - accuracy: 0.4568 - val_loss: 1.2410 - val_accuracy: 0.4888
# Epoch 12/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.2352 - accuracy: 0.4653 - val_loss: 1.1987 - val_accuracy: 0.4928
# Epoch 13/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.2264 - accuracy: 0.4765 - val_loss: 1.1830 - val_accuracy: 0.5120
# Epoch 14/100
# 47/47 [==============================] - 4s 76ms/step - loss: 1.2139 - accuracy: 0.4866 - val_loss: 1.1726 - val_accuracy: 0.5287
# Epoch 15/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.2149 - accuracy: 0.4834 - val_loss: 1.1703 - val_accuracy: 0.5367
# Epoch 16/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.1985 - accuracy: 0.4937 - val_loss: 1.1627 - val_accuracy: 0.5415
# Epoch 17/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.1974 - accuracy: 0.4887 - val_loss: 1.2125 - val_accuracy: 0.4833
# Epoch 18/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1815 - accuracy: 0.4969 - val_loss: 1.1449 - val_accuracy: 0.5072
# Epoch 19/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1781 - accuracy: 0.4914 - val_loss: 1.1506 - val_accuracy: 0.5375
# Epoch 20/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1618 - accuracy: 0.5039 - val_loss: 1.1233 - val_accuracy: 0.5319
# Epoch 21/100
# 47/47 [==============================] - 4s 76ms/step - loss: 1.1593 - accuracy: 0.4988 - val_loss: 1.1253 - val_accuracy: 0.5439
# Epoch 22/100
# 47/47 [==============================] - 4s 76ms/step - loss: 1.1583 - accuracy: 0.5028 - val_loss: 1.1086 - val_accuracy: 0.5518
# Epoch 23/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.1620 - accuracy: 0.5044 - val_loss: 1.1451 - val_accuracy: 0.5000
# Epoch 24/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.1388 - accuracy: 0.5225 - val_loss: 1.0955 - val_accuracy: 0.5375
# Epoch 25/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1383 - accuracy: 0.5055 - val_loss: 1.1015 - val_accuracy: 0.5423
# Epoch 26/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.1356 - accuracy: 0.5105 - val_loss: 1.0858 - val_accuracy: 0.5415
# Epoch 27/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1361 - accuracy: 0.5142 - val_loss: 1.1348 - val_accuracy: 0.5335
# Epoch 28/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.1364 - accuracy: 0.5025 - val_loss: 1.0768 - val_accuracy: 0.5447
# Epoch 29/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.1072 - accuracy: 0.5243 - val_loss: 1.0627 - val_accuracy: 0.5526
# Epoch 30/100
# 47/47 [==============================] - 4s 76ms/step - loss: 1.1172 - accuracy: 0.5145 - val_loss: 1.0589 - val_accuracy: 0.5622
# Epoch 31/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.1014 - accuracy: 0.5270 - val_loss: 1.0540 - val_accuracy: 0.5590
# Epoch 32/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0913 - accuracy: 0.5360 - val_loss: 1.0455 - val_accuracy: 0.5638
# Epoch 33/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.1140 - accuracy: 0.5065 - val_loss: 1.1259 - val_accuracy: 0.4912
# Epoch 34/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0903 - accuracy: 0.5227 - val_loss: 1.0421 - val_accuracy: 0.5582
# Epoch 35/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0772 - accuracy: 0.5342 - val_loss: 1.0923 - val_accuracy: 0.5486
# Epoch 36/100
# 47/47 [==============================] - 4s 76ms/step - loss: 1.0743 - accuracy: 0.5355 - val_loss: 1.0248 - val_accuracy: 0.5758
# Epoch 37/100
# 47/47 [==============================] - 4s 76ms/step - loss: 1.0758 - accuracy: 0.5289 - val_loss: 1.0232 - val_accuracy: 0.5917
# Epoch 38/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0628 - accuracy: 0.5400 - val_loss: 1.0516 - val_accuracy: 0.5327
# Epoch 39/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0544 - accuracy: 0.5467 - val_loss: 1.0064 - val_accuracy: 0.5686
# Epoch 40/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0698 - accuracy: 0.5443 - val_loss: 1.0034 - val_accuracy: 0.5774
# Epoch 41/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0511 - accuracy: 0.5422 - val_loss: 1.2320 - val_accuracy: 0.4386
# Epoch 42/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0667 - accuracy: 0.5416 - val_loss: 1.0730 - val_accuracy: 0.5486
# Epoch 43/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0499 - accuracy: 0.5443 - val_loss: 0.9785 - val_accuracy: 0.5965
# Epoch 44/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0637 - accuracy: 0.5382 - val_loss: 1.0119 - val_accuracy: 0.5550
# Epoch 45/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0150 - accuracy: 0.5523 - val_loss: 0.9743 - val_accuracy: 0.5869
# Epoch 46/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0257 - accuracy: 0.5499 - val_loss: 0.9969 - val_accuracy: 0.5494
# Epoch 47/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0028 - accuracy: 0.5738 - val_loss: 1.0539 - val_accuracy: 0.5311
# Epoch 48/100
# 47/47 [==============================] - 4s 75ms/step - loss: 1.0140 - accuracy: 0.5571 - val_loss: 0.9859 - val_accuracy: 0.5774
# Epoch 49/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9843 - accuracy: 0.5818 - val_loss: 0.9560 - val_accuracy: 0.5869
# Epoch 50/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0115 - accuracy: 0.5693 - val_loss: 0.9970 - val_accuracy: 0.5694
# Epoch 51/100
# 47/47 [==============================] - 3s 75ms/step - loss: 1.0035 - accuracy: 0.5557 - val_loss: 1.0559 - val_accuracy: 0.5215
# Epoch 52/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.9745 - accuracy: 0.5842 - val_loss: 0.9587 - val_accuracy: 0.5805
# Epoch 53/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0016 - accuracy: 0.5637 - val_loss: 0.9396 - val_accuracy: 0.5893
# Epoch 54/100
# 47/47 [==============================] - 3s 74ms/step - loss: 1.0021 - accuracy: 0.5744 - val_loss: 1.0348 - val_accuracy: 0.5750
# Epoch 55/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9759 - accuracy: 0.5733 - val_loss: 0.9357 - val_accuracy: 0.5973
# Epoch 56/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.9943 - accuracy: 0.5738 - val_loss: 0.9519 - val_accuracy: 0.6005
# Epoch 57/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9664 - accuracy: 0.5943 - val_loss: 1.0060 - val_accuracy: 0.5470
# Epoch 58/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9674 - accuracy: 0.5887 - val_loss: 0.9186 - val_accuracy: 0.5997
# Epoch 59/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9692 - accuracy: 0.5850 - val_loss: 0.9272 - val_accuracy: 0.5949
# Epoch 60/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.9497 - accuracy: 0.5935 - val_loss: 0.9133 - val_accuracy: 0.6021
# Epoch 61/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9358 - accuracy: 0.6028 - val_loss: 0.9379 - val_accuracy: 0.5885
# Epoch 62/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9574 - accuracy: 0.5940 - val_loss: 0.9423 - val_accuracy: 0.5821
# Epoch 63/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.9511 - accuracy: 0.5964 - val_loss: 1.2802 - val_accuracy: 0.4314
# Epoch 64/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.9368 - accuracy: 0.6071 - val_loss: 1.0542 - val_accuracy: 0.5247
# Epoch 65/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.9232 - accuracy: 0.6132 - val_loss: 0.9079 - val_accuracy: 0.6124
# Epoch 66/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9101 - accuracy: 0.6185 - val_loss: 0.9532 - val_accuracy: 0.5957
# Epoch 67/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9291 - accuracy: 0.6026 - val_loss: 0.9251 - val_accuracy: 0.6100
# Epoch 68/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9252 - accuracy: 0.6124 - val_loss: 0.9065 - val_accuracy: 0.6093
# Epoch 69/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9295 - accuracy: 0.6257 - val_loss: 0.9532 - val_accuracy: 0.5893
# Epoch 70/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9112 - accuracy: 0.6100 - val_loss: 0.8941 - val_accuracy: 0.6180
# Epoch 71/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.9340 - accuracy: 0.6121 - val_loss: 0.9740 - val_accuracy: 0.5933
# Epoch 72/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9192 - accuracy: 0.6140 - val_loss: 0.9557 - val_accuracy: 0.6100
# Epoch 73/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9136 - accuracy: 0.6225 - val_loss: 0.9277 - val_accuracy: 0.6053
# Epoch 74/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.9022 - accuracy: 0.6236 - val_loss: 0.9910 - val_accuracy: 0.5478
# Epoch 75/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9141 - accuracy: 0.6113 - val_loss: 0.8946 - val_accuracy: 0.6132
# Epoch 76/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.8913 - accuracy: 0.6310 - val_loss: 1.4755 - val_accuracy: 0.3796
# Epoch 77/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.9268 - accuracy: 0.6028 - val_loss: 0.8770 - val_accuracy: 0.6244
# Epoch 78/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.8938 - accuracy: 0.6334 - val_loss: 0.9299 - val_accuracy: 0.5989
# Epoch 79/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.8776 - accuracy: 0.6347 - val_loss: 1.0183 - val_accuracy: 0.5742
# Epoch 80/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.8942 - accuracy: 0.6260 - val_loss: 0.9564 - val_accuracy: 0.6085
# Epoch 81/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.8798 - accuracy: 0.6366 - val_loss: 1.1103 - val_accuracy: 0.5016
# Epoch 82/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.8703 - accuracy: 0.6454 - val_loss: 0.8878 - val_accuracy: 0.6268
# Epoch 83/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.8955 - accuracy: 0.6339 - val_loss: 0.9528 - val_accuracy: 0.5813
# Epoch 84/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9046 - accuracy: 0.6193 - val_loss: 1.1363 - val_accuracy: 0.5040
# Epoch 85/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.8789 - accuracy: 0.6395 - val_loss: 0.8756 - val_accuracy: 0.6252
# Epoch 86/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.8574 - accuracy: 0.6414 - val_loss: 0.9043 - val_accuracy: 0.6180
# Epoch 87/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.8813 - accuracy: 0.6385 - val_loss: 0.8736 - val_accuracy: 0.6196
# Epoch 88/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.8417 - accuracy: 0.6534 - val_loss: 1.0280 - val_accuracy: 0.5598
# Epoch 89/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.8694 - accuracy: 0.6366 - val_loss: 0.9367 - val_accuracy: 0.6093
# Epoch 90/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.8996 - accuracy: 0.6257 - val_loss: 0.8768 - val_accuracy: 0.6228
# Epoch 91/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.9083 - accuracy: 0.6164 - val_loss: 0.9778 - val_accuracy: 0.5598
# Epoch 92/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.8476 - accuracy: 0.6560 - val_loss: 0.9222 - val_accuracy: 0.5933
# Epoch 93/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.9343 - accuracy: 0.6153 - val_loss: 0.9426 - val_accuracy: 0.5965
# Epoch 94/100
# 47/47 [==============================] - 4s 76ms/step - loss: 0.8829 - accuracy: 0.6355 - val_loss: 0.8676 - val_accuracy: 0.6316
# Epoch 95/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.8272 - accuracy: 0.6605 - val_loss: 0.8987 - val_accuracy: 0.6172
# Epoch 96/100
# 47/47 [==============================] - 3s 75ms/step - loss: 0.8587 - accuracy: 0.6459 - val_loss: 1.0650 - val_accuracy: 0.5686
# Epoch 97/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.8478 - accuracy: 0.6528 - val_loss: 0.8676 - val_accuracy: 0.6340
# Epoch 98/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.8241 - accuracy: 0.6629 - val_loss: 0.9598 - val_accuracy: 0.5893
# Epoch 99/100
# 47/47 [==============================] - 3s 74ms/step - loss: 0.8397 - accuracy: 0.6518 - val_loss: 0.8918 - val_accuracy: 0.6188
# Epoch 100/100
# 47/47 [==============================] - 4s 75ms/step - loss: 0.8191 - accuracy: 0.6675 - val_loss: 0.8907 - val_accuracy: 0.6411
# 40/40 [==============================] - 2s 28ms/step

# %%
vgg_model.predict([basic_bundle.X_tei, basic_bundle.X_tep])
# Out:
# 28/40 [====================>.........] - ETA: 0s

# %%
# Val acc. and Val loss evolution
plot_acc_loss(vgg_model.fit)

# %%
# ROC curves
plot_ROC(vgg_model.predictions,basic_bundle.y_test_onehot,4)

# %%
# Confusion matrix
plot_cm(basic_bundle.y_test_onehot,vgg_model.predictions)

# %%
# Clasification report
print(classification_report(np.argmax(basic_bundle.y_test_onehot, axis=1), np.argmax(vgg_model.predictions, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.85      0.79       342
#            1       0.58      0.32      0.41       270
#            2       0.53      0.57      0.55       316
#            3       0.69      0.78      0.73       325
#
#     accuracy                           0.65      1253
#    macro avg       0.63      0.63      0.62      1253
# weighted avg       0.64      0.65      0.63      1253

# %%
#vgg_model.save("/content/drive/MyDrive/Thesis/M224A-1000/vgg16_hdi_224A_1000_v1.h5")
